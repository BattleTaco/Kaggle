# %%
# ============================================================
# Store Sales – Time Series Forecasting (my end-to-end notebook)
# Michael Ramirez — first-person, production-minded, submission-ready
# ============================================================
#
# What I’m doing here:
# 1) Load + sanity-check all tables from the competition.
# 2) Build a clean date calendar (dow, dom, month, etc.), paydays (15/EOM),
#    earthquake window features, oil price rolls, and holiday flags.
# 3) Safely merge everything, typed categoricals, and create leak-free
#    per-(store_nbr, family) lags/rolling means for `sales`.
# 4) Use a robust sklearn ColumnTransformer (OHE for cats, passthrough nums).
# 5) TimeSeriesSplit CV (RMSLE) to verify the approach.
# 6) Train a final XGBoost model (GPU if available—auto fallback to CPU),
#    generate `submission.csv`, and save minimal artifacts.
#
# Design notes:
# - No deep learning. Classical GBDT with careful feature engineering wins here.
# - No parameter knobs in .fit() that break cross-version (I keep it version-safe).
# - I don’t rely on leakage; all target-based features are lagged/rolled properly.
# - Matplotlib only for visuals (I keep plotting optional/minimal for Kaggle speed).
#
# Tip for Kaggle:
# - Set Accelerator = GPU in the Notebook settings to speed up training.
# - This single notebook produces `submission.csv` in Outputs.
# ============================================================

import os
import json
import math
import warnings
from dataclasses import dataclass, asdict
from typing import Dict, Any, Tuple, List, Optional

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt  # used lightly; safe for headless

from packaging import version

# sklearn
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_log_error

# xgboost
import xgboost as xgb
from xgboost import XGBRegressor

warnings.filterwarnings("ignore")

# ----------------------------
# Reproducibility + Paths
# ----------------------------
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

KAGGLE_DIR = "/kaggle/input/store-sales-time-series-forecasting"
LOCAL_DIR = os.environ.get("DATA_DIR", "")
DATA_DIR = KAGGLE_DIR if os.path.exists(KAGGLE_DIR) else LOCAL_DIR

RUN_ID = pd.Timestamp.now().strftime("%Y%m%d-%H%M%S")
ARTIFACTS_DIR = f"./artifacts_{RUN_ID}"
os.makedirs(ARTIFACTS_DIR, exist_ok=True)

# ----------------------------
# Config (kept flat and explicit)
# ----------------------------
@dataclass
class Config:
    target_col: str = "sales"
    date_col: str = "date"
    id_cols: Tuple[str, str] = ("store_nbr", "family")
    onpromotion_col: str = "onpromotion"

    sales_lags: Tuple[int, ...] = (1, 7, 14, 28)
    sales_rolls: Tuple[int, ...] = (7, 14, 28)

    oil_rolls: Tuple[int, ...] = (7, 14, 28)
    earthquake_date: str = "2016-04-16"
    earthquake_window_days: int = 45
    payday_days: Tuple[int, int] = (15, -1)  # 15th + month-end

    # Model knobs (conservative; I prefer stability over flashy params)
    xgb_params: Dict[str, Any] = None
    n_splits_ts: int = 3
    eval_metric: str = "rmse"

cfg = Config(
    xgb_params=dict(
        n_estimators=2000,
        learning_rate=0.05,
        max_depth=8,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_lambda=1.0,
        tree_method="hist",   # will be overridden if GPU is present (2.x -> device='cuda' / 1.x -> gpu_hist)
        n_jobs=-1,
        random_state=RANDOM_STATE,
    )
)

with open(os.path.join(ARTIFACTS_DIR, "config.json"), "w") as f:
    json.dump(asdict(cfg), f, indent=2)


# ----------------------------
# Helpers
# ----------------------------
def mem_usage(df: pd.DataFrame) -> str:
    return f"{df.memory_usage(deep=True).sum() / 1024**2:.2f} MB"

def rmsle(y_true, y_pred) -> float:
    y_true = np.maximum(y_true, 0.0)
    y_pred = np.maximum(y_pred, 0.0)
    return math.sqrt(mean_squared_log_error(y_true, y_pred))


# ----------------------------
# Load Data (dtypes for memory)
# ----------------------------
dtype_train = {
    "store_nbr": "int16",
    "family": "category",
    "onpromotion": "float32",
    "sales": "float32",
}
dtype_test = {
    "store_nbr": "int16",
    "family": "category",
    "onpromotion": "float32",
}

train = pd.read_csv(os.path.join(DATA_DIR, "train.csv"), parse_dates=["date"], dtype=dtype_train)
test  = pd.read_csv(os.path.join(DATA_DIR, "test.csv"),  parse_dates=["date"], dtype=dtype_test)
stores = pd.read_csv(os.path.join(DATA_DIR, "stores.csv"))
oil    = pd.read_csv(os.path.join(DATA_DIR, "oil.csv"), parse_dates=["date"])
hol    = pd.read_csv(os.path.join(DATA_DIR, "holidays_events.csv"), parse_dates=["date"])

print("Train:", train.shape, mem_usage(train))
print("Test :", test.shape, mem_usage(test))


# ----------------------------
# Calendar & Aux Features
# ----------------------------
def add_calendar_parts(cal: pd.DataFrame, date_col: str = "date") -> pd.DataFrame:
    dt = cal[date_col]
    cal["dow"] = dt.dt.weekday.astype("int8")  # Mon=0
    cal["dom"] = dt.dt.day.astype("int8")
    cal["month"] = dt.dt.month.astype("int8")
    cal["year"] = dt.dt.year.astype("int16")
    cal["doy"] = dt.dt.dayofyear.astype("int16")
    cal["wom"] = ((cal["dom"] - 1) // 7 + 1).astype("int8")
    return cal

def add_paydays(cal: pd.DataFrame, date_col="date", days=(15, -1)) -> pd.DataFrame:
    d = cal.copy()
    d["is_payday_15"] = (d[date_col].dt.day == days[0]).astype("int8")
    month_end = (d[date_col] + pd.offsets.MonthEnd(0)).dt.day
    d["is_payday_eom"] = (d[date_col].dt.day == month_end).astype("int8")
    d["days_to_15"] = (d[date_col].dt.day - days[0]).abs().clip(0, 10).astype("int8")
    d["days_to_eom"] = (month_end - d[date_col].dt.day).abs().clip(0, 10).astype("int8")
    return d

def add_earthquake(cal: pd.DataFrame, quake_date: str, window_days: int) -> pd.DataFrame:
    d = cal.copy()
    qd = pd.to_datetime(quake_date)
    delta = (d["date"] - qd).dt.days
    d["days_since_quake"] = delta.clip(lower=-365, upper=365).astype("int16")
    d["is_quake_window"] = ((delta >= 0) & (delta <= window_days)).astype("int8")
    return d

def prepare_oil(oil_df: pd.DataFrame) -> pd.DataFrame:
    o = oil_df.rename(columns={"dcoilwtico": "oil_price"}).copy()
    full_range = pd.date_range(o["date"].min(), o["date"].max(), freq="D")
    o = o.set_index("date").reindex(full_range).rename_axis("date").reset_index()
    o["oil_price"] = o["oil_price"].ffill()
    return o

def add_oil_rolls(cal: pd.DataFrame, oil_df: pd.DataFrame, rolls=(7, 14, 28)) -> pd.DataFrame:
    o = prepare_oil(oil_df)
    c = cal.merge(o, on="date", how="left")
    for w in rolls:
        c[f"oil_rollmean_{w}"] = c["oil_price"].rolling(w, min_periods=max(2, w//2)).mean()
    return c

def prepare_holidays(hol: pd.DataFrame) -> pd.DataFrame:
    h = hol.copy()
    h["is_holiday_base"] = ((h["type"].isin(["Holiday", "Transfer"])) & (h["transferred"] == False)).astype("int8")
    h["is_transferred_from"] = ((h["type"] == "Holiday") & (h["transferred"] == True)).astype("int8")
    h["is_bridge"] = (h["type"] == "Bridge").astype("int8")
    h["is_work_day"] = (h["type"] == "Work Day").astype("int8")
    h["is_additional"] = (h["type"] == "Additional").astype("int8")
    agg = h.groupby("date", as_index=False)[["is_holiday_base","is_transferred_from","is_bridge","is_work_day","is_additional"]].max()
    agg["is_holiday"] = ((agg["is_holiday_base"] == 1) | (agg["is_transferred_from"] == 1)).astype("int8")
    return agg

mind = min(train["date"].min(), test["date"].min())
maxd = max(train["date"].max(), test["date"].max())
calendar = pd.DataFrame({"date": pd.date_range(mind, maxd, freq="D")})
calendar = add_calendar_parts(calendar)
calendar = add_paydays(calendar, "date", cfg.payday_days)
calendar = add_earthquake(calendar, cfg.earthquake_date, cfg.earthquake_window_days)
calendar = add_oil_rolls(calendar, oil, cfg.oil_rolls)
hol_agg = prepare_holidays(hol)
calendar = calendar.merge(hol_agg, on="date", how="left")
calendar[["is_holiday","is_bridge","is_work_day","is_additional"]] = \
    calendar[["is_holiday","is_bridge","is_work_day","is_additional"]].fillna(0).astype("int8")
calendar["oil_price"] = calendar["oil_price"].ffill()

# ----------------------------
# Merge store metadata + calendar
# ----------------------------
stores_renamed = stores.rename(columns={"type": "store_type"}).copy()

for df in (train, test):
    df["onpromotion"] = df["onpromotion"].fillna(0).astype("float32")

train = train.merge(stores_renamed, on="store_nbr", how="left")
test  = test.merge(stores_renamed, on="store_nbr", how="left")

train = train.merge(calendar, on="date", how="left")
test  = test.merge(calendar, on="date", how="left")

for c in ["city", "state", "store_type"]:
    train[c] = train[c].astype("category")
    test[c]  = test[c].astype("category")

# ----------------------------
# Leak-free lags/rolls by (store_nbr, family)
# ----------------------------
def add_group_lag_roll(df_all: pd.DataFrame, cfg: Config) -> pd.DataFrame:
    df = df_all.sort_values(["store_nbr", "family", "date"]).copy()
    g = ["store_nbr", "family"]
    for lag in cfg.sales_lags:
        df[f"sales_lag_{lag}"] = df.groupby(g)["sales"].shift(lag)
    for w in cfg.sales_rolls:
        df[f"sales_rollmean_{w}"] = (
            df.groupby(g)["sales"].apply(lambda s: s.shift(1).rolling(window=w, min_periods=max(2, w//2)).mean())
              .reset_index(level=g, drop=True)
        )
    return df

test_with_sales = test.copy()
test_with_sales["sales"] = np.nan
all_df = pd.concat([train, test_with_sales], axis=0, ignore_index=True)

all_df = add_group_lag_roll(all_df, cfg)

train = all_df[all_df["sales"].notna()].copy()
test  = all_df[all_df["sales"].isna()].copy().drop(columns=["sales"])

lag_roll_cols = [c for c in train.columns if c.startswith("sales_lag_") or c.startswith("sales_rollmean_")]
for c in lag_roll_cols:
    train[c] = train[c].fillna(0.0).astype("float32")
    test[c]  = test[c].fillna(0.0).astype("float32")

# ----------------------------
# Feature matrix
# ----------------------------
TARGET = cfg.target_col

categorical_cols = ["family","city","state","store_type","cluster"]
train["cluster"] = train["cluster"].astype(str).astype("category")
test["cluster"]  = test["cluster"].astype(str).astype("category")

numeric_cols = [
    "store_nbr","onpromotion",
    "dow","dom","month","year","doy","wom",
    "is_payday_15","is_payday_eom","days_to_15","days_to_eom",
    "days_since_quake","is_quake_window",
    "oil_price","oil_rollmean_7","oil_rollmean_14","oil_rollmean_28",
    "is_holiday","is_bridge","is_work_day","is_additional",
] + lag_roll_cols

feature_cols = categorical_cols + numeric_cols

X = train[feature_cols].copy()
y = train[TARGET].astype("float32").values

# sklearn version-safe OHE arg
import sklearn
if version.parse(sklearn.__version__) >= version.parse("1.2"):
    ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=True)
else:
    ohe = OneHotEncoder(handle_unknown="ignore", sparse=True)

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", ohe, categorical_cols),
        ("num", "passthrough", numeric_cols),
    ],
    remainder="drop"
)

# ----------------------------
# TimeSeriesSplit CV (RMSLE)
# ----------------------------
train_sorted_idx = np.argsort(train["date"].values)
X_sorted = X.iloc[train_sorted_idx]
y_sorted = y[train_sorted_idx]

tscv = TimeSeriesSplit(n_splits=cfg.n_splits_ts)

# XGBoost GPU handling (version-safe)
gpu_params = {}
if version.parse(xgb.__version__) >= version.parse("2.0.0"):
    gpu_params.update({"device": "cuda"})  # 2.x
else:
    gpu_params.update({"tree_method": "gpu_hist", "predictor": "gpu_predictor"})  # 1.x

def build_model_params(base: dict) -> dict:
    mp = dict(base) if base is not None else {}
    mp.update(gpu_params)
    mp.setdefault("verbosity", 0)
    mp.setdefault("eval_metric", cfg.eval_metric)
    return mp

fold_scores = []
feature_names_out = None

for fold, (tr_idx, va_idx) in enumerate(tscv.split(X_sorted), 1):
    X_tr_raw, X_va_raw = X_sorted.iloc[tr_idx], X_sorted.iloc[va_idx]
    y_tr, y_va = y_sorted[tr_idx], y_sorted[va_idx]

    Xt = preprocessor.fit_transform(X_tr_raw)
    Xv = preprocessor.transform(X_va_raw)

    params = build_model_params(cfg.xgb_params)
    try:
        model = XGBRegressor(**params)
        model.fit(Xt, y_tr, eval_set=[(Xv, y_va)])
    except xgb.core.XGBoostError as e:
        print("[WARN] GPU failed; falling back to CPU ->", str(e))
        params.pop("device", None)
        params["tree_method"] = "hist"
        params["predictor"] = "auto"
        model = XGBRegressor(**params)
        model.fit(Xt, y_tr, eval_set=[(Xv, y_va)])

    va_pred = np.maximum(model.predict(Xv), 0.0)
    score = rmsle(y_va, va_pred)
    fold_scores.append(score)
    print(f"Fold {fold}: RMSLE={score:.5f}")

    if feature_names_out is None:
        try:
            cat_features = list(preprocessor.named_transformers_["cat"].get_feature_names_out(categorical_cols))
            feature_names_out = cat_features + numeric_cols
        except Exception:
            feature_names_out = None

print("CV RMSLE:", fold_scores, "| Mean:", float(np.mean(fold_scores)))
with open(os.path.join(ARTIFACTS_DIR, "cv_metrics.json"), "w") as f:
    json.dump({"fold_rmsle": [float(s) for s in fold_scores],
               "mean_rmsle": float(np.mean(fold_scores))}, f, indent=2)

# ----------------------------
# Final fit on (train + last val chunk), predict test, write submission
# ----------------------------
last_tr_idx, last_va_idx = list(tscv.split(X_sorted))[-1]
X_tr_raw = X_sorted.iloc[last_tr_idx]; X_va_raw = X_sorted.iloc[last_va_idx]
y_tr = y_sorted[last_tr_idx]; y_va = y_sorted[last_va_idx]

# fresh preprocessor for deployment
preprocessor_full = ColumnTransformer(
    transformers=[
        ("cat", ohe, categorical_cols),
        ("num", "passthrough", numeric_cols),
    ],
    remainder="drop"
)

X_tr_all = pd.concat([X_tr_raw, X_va_raw], axis=0)
y_tr_all = np.concatenate([y_tr, y_va], axis=0)

X_tr_all_t = preprocessor_full.fit_transform(X_tr_all)
X_val_t    = preprocessor_full.transform(X_va_raw)

params = build_model_params(cfg.xgb_params)
try:
    model_full = XGBRegressor(**params)
    model_full.fit(X_tr_all_t, y_tr_all, eval_set=[(X_val_t, y_va)])
except xgb.core.XGBoostError as e:
    print("[WARN] GPU failed; falling back to CPU ->", str(e))
    params.pop("device", None)
    params["tree_method"] = "hist"
    params["predictor"] = "auto"
    model_full = XGBRegressor(**params)
    model_full.fit(X_tr_all_t, y_tr_all, eval_set=[(X_val_t, y_va)])

# test transform + predict
X_test = test[feature_cols].copy()
X_test_t = preprocessor_full.transform(X_test)
test_pred = np.maximum(model_full.predict(X_test_t), 0.0)

# submission
sample = pd.read_csv(os.path.join(DATA_DIR, "sample_submission.csv"))
submission = sample.copy()
submission["sales"] = test_pred
sub_path = os.path.join(ARTIFACTS_DIR, f"submission_{RUN_ID}.csv")
submission.to_csv(sub_path, index=False)
print("Wrote:", sub_path)

# Save minimal artifacts (handy for debugging offline)
import joblib
joblib.dump(model_full, os.path.join(ARTIFACTS_DIR, "model_xgb.joblib"))
joblib.dump(preprocessor_full, os.path.join(ARTIFACTS_DIR, "preprocessor.joblib"))
with open(os.path.join(ARTIFACTS_DIR, "feature_names.json"), "w") as f:
    json.dump(feature_names_out, f, indent=2)

# Also emit a copy named exactly 'submission.csv' for Kaggle auto-pickup in Outputs
submission.to_csv("submission.csv", index=False)
print("submission.csv saved (ready to Submit to Competition)")
# Out:
# Train: (3000888, 6) 77.27 MB
# Test : (28512, 5) 0.63 MB
# [0]	validation_0-rmse:937.34750
# [1]	validation_0-rmse:895.40563
# [2]	validation_0-rmse:856.17577
# [3]	validation_0-rmse:818.70397
# [4]	validation_0-rmse:783.53362
# [5]	validation_0-rmse:750.03482
# [6]	validation_0-rmse:718.26120
# [7]	validation_0-rmse:688.04253
# [8]	validation_0-rmse:659.63321
# [9]	validation_0-rmse:633.25712
# [10]	validation_0-rmse:607.97543
# [11]	validation_0-rmse:584.19573
# [12]	validation_0-rmse:561.28865
# [13]	validation_0-rmse:540.52994
# [14]	validation_0-rmse:520.52535
# [15]	validation_0-rmse:502.20271
# [16]	validation_0-rmse:484.09453
# [17]	validation_0-rmse:465.05128
# [18]	validation_0-rmse:449.56676
# [19]	validation_0-rmse:434.53053
# [20]	validation_0-rmse:420.33526
# [21]	validation_0-rmse:407.49145
# [22]	validation_0-rmse:395.47605
# [23]	validation_0-rmse:383.87620
# [24]	validation_0-rmse:373.40752
# [25]	validation_0-rmse:363.36987
# [26]	validation_0-rmse:353.97553
# [27]	validation_0-rmse:345.29632
# [28]	validation_0-rmse:335.47514
# [29]	validation_0-rmse:327.77949
# [30]	validation_0-rmse:320.55895
# [31]	validation_0-rmse:314.19713
# [32]	validation_0-rmse:307.69787
# [33]	validation_0-rmse:301.80489
# [34]	validation_0-rmse:296.57765
# [35]	validation_0-rmse:291.62881
# [36]	validation_0-rmse:287.07863
# [37]	validation_0-rmse:282.87669
# [38]	validation_0-rmse:279.19602
# [39]	validation_0-rmse:275.39200
# [40]	validation_0-rmse:272.52409
# [41]	validation_0-rmse:269.52631
# [42]	validation_0-rmse:266.80384
# [43]	validation_0-rmse:264.33422
# [44]	validation_0-rmse:261.98476
# [45]	validation_0-rmse:260.18057
# [46]	validation_0-rmse:258.07381
# [47]	validation_0-rmse:256.06885
# [48]	validation_0-rmse:254.36868
# [49]	validation_0-rmse:252.77134
# [50]	validation_0-rmse:251.44577
# [51]	validation_0-rmse:250.07801
# [52]	validation_0-rmse:248.70224
# [53]	validation_0-rmse:247.68899
# [54]	validation_0-rmse:246.71619
# [55]	validation_0-rmse:245.84113
# [56]	validation_0-rmse:245.12639
# [57]	validation_0-rmse:244.38193
# [58]	validation_0-rmse:243.36095
# [59]	validation_0-rmse:242.74933
# [60]	validation_0-rmse:242.18615
# [61]	validation_0-rmse:241.91875
# [62]	validation_0-rmse:241.38467
# [63]	validation_0-rmse:240.96498
# [64]	validation_0-rmse:240.54366
# [65]	validation_0-rmse:240.33430
# [66]	validation_0-rmse:240.10735
# [67]	validation_0-rmse:240.06884
# [68]	validation_0-rmse:239.95365
# [69]	validation_0-rmse:239.70660
# [70]	validation_0-rmse:239.32268
# [71]	validation_0-rmse:239.35321
# [72]	validation_0-rmse:239.16645
# [73]	validation_0-rmse:239.02438
# [74]	validation_0-rmse:239.23794
# [75]	validation_0-rmse:239.09573
# [76]	validation_0-rmse:239.00351
# [77]	validation_0-rmse:238.83642
# [78]	validation_0-rmse:238.76242
# [79]	validation_0-rmse:238.87698
# [80]	validation_0-rmse:238.89174
# [81]	validation_0-rmse:238.67388
# [82]	validation_0-rmse:238.61909
# [83]	validation_0-rmse:238.45564
# [84]	validation_0-rmse:238.51587
# [85]	validation_0-rmse:238.56690
# [86]	validation_0-rmse:238.44557
# [87]	validation_0-rmse:238.41309
# [88]	validation_0-rmse:238.44872
# [89]	validation_0-rmse:238.49177
# [90]	validation_0-rmse:238.32168
# [91]	validation_0-rmse:238.30980
# [92]	validation_0-rmse:238.46963
# [93]	validation_0-rmse:238.30631
# [94]	validation_0-rmse:238.22898
# [95]	validation_0-rmse:238.30278
# [96]	validation_0-rmse:238.23334
# [97]	validation_0-rmse:238.31394
# [98]	validation_0-rmse:238.10688
# [99]	validation_0-rmse:238.04557
# [100]	validation_0-rmse:238.03191
# [101]	validation_0-rmse:237.99906
# [102]	validation_0-rmse:237.94269
# [103]	validation_0-rmse:237.90118
# [104]	validation_0-rmse:237.88512
# [105]	validation_0-rmse:237.90686
# [106]	validation_0-rmse:237.84395
# [107]	validation_0-rmse:237.73395
# [108]	validation_0-rmse:237.82932
# [109]	validation_0-rmse:237.85339
# [110]	validation_0-rmse:237.65937
# [111]	validation_0-rmse:237.83998
# [112]	validation_0-rmse:237.86939
# [113]	validation_0-rmse:237.88739
# [114]	validation_0-rmse:238.01587
# [115]	validation_0-rmse:238.05796
# [116]	validation_0-rmse:238.00727
# [117]	validation_0-rmse:237.95968
# [118]	validation_0-rmse:237.92008
# [119]	validation_0-rmse:237.95099
# [120]	validation_0-rmse:238.25172
# [121]	validation_0-rmse:238.32108
# [122]	validation_0-rmse:238.38047
# [123]	validation_0-rmse:238.40131
# [124]	validation_0-rmse:238.46807
# [125]	validation_0-rmse:238.41387
# [126]	validation_0-rmse:238.40857
# [127]	validation_0-rmse:238.35872
# [128]	validation_0-rmse:238.34295
# [129]	validation_0-rmse:238.23493
# [130]	validation_0-rmse:238.22712
# [131]	validation_0-rmse:238.32890
# [132]	validation_0-rmse:238.36573
# [133]	validation_0-rmse:238.38807
# [134]	validation_0-rmse:238.47018
# [135]	validation_0-rmse:238.47705
# [136]	validation_0-rmse:238.68137
# [137]	validation_0-rmse:238.75542
# [138]	validation_0-rmse:238.88166
# [139]	validation_0-rmse:238.92564
# [140]	validation_0-rmse:239.11034
# [141]	validation_0-rmse:239.36440
# [142]	validation_0-rmse:239.36703
# [143]	validation_0-rmse:239.32440
# [144]	validation_0-rmse:239.46781
# [145]	validation_0-rmse:239.49744
# [146]	validation_0-rmse:239.51127
# [147]	validation_0-rmse:239.50245
# [148]	validation_0-rmse:239.59793
# [149]	validation_0-rmse:239.62854
# [150]	validation_0-rmse:239.80375
# [151]	validation_0-rmse:240.08118
# [152]	validation_0-rmse:240.21388
# [153]	validation_0-rmse:240.32367
# [154]	validation_0-rmse:240.56877
# [155]	validation_0-rmse:240.60514
# [156]	validation_0-rmse:240.74938
# [157]	validation_0-rmse:240.77872
# [158]	validation_0-rmse:240.80122
# [159]	validation_0-rmse:240.78837
# [160]	validation_0-rmse:240.81658
# [161]	validation_0-rmse:240.92388
# [162]	validation_0-rmse:240.91088
# [163]	validation_0-rmse:240.93310
# [164]	validation_0-rmse:240.94737
# [165]	validation_0-rmse:240.94537
# [166]	validation_0-rmse:240.91591
# [167]	validation_0-rmse:241.05139
# [168]	validation_0-rmse:241.09089
# [169]	validation_0-rmse:241.20433
# [170]	validation_0-rmse:241.32042
# [171]	validation_0-rmse:241.37172
# [172]	validation_0-rmse:241.36553
# [173]	validation_0-rmse:241.52060
# [174]	validation_0-rmse:241.78479
# [175]	validation_0-rmse:241.84415
# [176]	validation_0-rmse:241.84436
# [177]	validation_0-rmse:242.05101
# [178]	validation_0-rmse:242.06543
# [179]	validation_0-rmse:242.24894
# [180]	validation_0-rmse:242.33373
# [181]	validation_0-rmse:242.28835
# [182]	validation_0-rmse:242.57717
# [183]	validation_0-rmse:242.66331
# [184]	validation_0-rmse:242.75555
# [185]	validation_0-rmse:242.83308
# [186]	validation_0-rmse:242.88829
# [187]	validation_0-rmse:242.88167
# [188]	validation_0-rmse:242.89444
# [189]	validation_0-rmse:243.00350
# [190]	validation_0-rmse:243.02208
# [191]	validation_0-rmse:243.07856
# [192]	validation_0-rmse:243.11123
# [193]	validation_0-rmse:243.31519
# [194]	validation_0-rmse:243.37103
# [195]	validation_0-rmse:243.46067
# [196]	validation_0-rmse:243.55358
# [197]	validation_0-rmse:243.61571
# [198]	validation_0-rmse:243.62790
# [199]	validation_0-rmse:243.77678
# [200]	validation_0-rmse:243.76157
# [201]	validation_0-rmse:243.68002
# [202]	validation_0-rmse:243.96740
# [203]	validation_0-rmse:243.92947
# [204]	validation_0-rmse:244.23624
# [205]	validation_0-rmse:244.23754
# [206]	validation_0-rmse:244.35714
# [207]	validation_0-rmse:244.49745
# [208]	validation_0-rmse:244.48695
# [209]	validation_0-rmse:244.47734
# [210]	validation_0-rmse:244.55157
# [211]	validation_0-rmse:244.43228
# [212]	validation_0-rmse:244.43578
# [213]	validation_0-rmse:244.40847
# [214]	validation_0-rmse:244.57460
# [215]	validation_0-rmse:244.63005
# [216]	validation_0-rmse:244.77149
# [217]	validation_0-rmse:244.81065
# [218]	validation_0-rmse:244.97006
# [219]	validation_0-rmse:245.00970
# [220]	validation_0-rmse:245.02549
# [221]	validation_0-rmse:245.13794
# [222]	validation_0-rmse:245.20512
# [223]	validation_0-rmse:245.45930
# [224]	validation_0-rmse:245.51076
# [225]	validation_0-rmse:245.59014
# [226]	validation_0-rmse:245.63968
# [227]	validation_0-rmse:245.65810
# [228]	validation_0-rmse:245.61714
# [229]	validation_0-rmse:245.65217
# [230]	validation_0-rmse:245.77564
# [231]	validation_0-rmse:245.89472
# [232]	validation_0-rmse:245.84813
# [233]	validation_0-rmse:245.83509
# [234]	validation_0-rmse:245.83226
# [235]	validation_0-rmse:245.91487
# [236]	validation_0-rmse:246.14303
# [237]	validation_0-rmse:246.08162
# [238]	validation_0-rmse:246.13776
# [239]	validation_0-rmse:246.42479
# [240]	validation_0-rmse:246.43459
# [241]	validation_0-rmse:246.54923
# [242]	validation_0-rmse:246.55256
# [243]	validation_0-rmse:246.53989
# [244]	validation_0-rmse:246.50450
# [245]	validation_0-rmse:246.58000
# [246]	validation_0-rmse:246.58646
# [247]	validation_0-rmse:246.61180
# [248]	validation_0-rmse:246.51871
# [249]	validation_0-rmse:246.65619
# [250]	validation_0-rmse:246.70592
# [251]	validation_0-rmse:246.72671
# [252]	validation_0-rmse:247.01883
# [253]	validation_0-rmse:247.02382
# [254]	validation_0-rmse:247.07863
# [255]	validation_0-rmse:247.12611
# [256]	validation_0-rmse:247.12852
# [257]	validation_0-rmse:247.15892
# [258]	validation_0-rmse:247.16795
# [259]	validation_0-rmse:247.16642
# [260]	validation_0-rmse:247.19055
# [261]	validation_0-rmse:247.23188
# [262]	validation_0-rmse:247.54823
# [263]	validation_0-rmse:247.54809
# [264]	validation_0-rmse:247.52943
# [265]	validation_0-rmse:247.78797
# [266]	validation_0-rmse:247.82541
# [267]	validation_0-rmse:247.85519
# [268]	validation_0-rmse:247.94784
# [269]	validation_0-rmse:247.97549
# [270]	validation_0-rmse:248.04690
# [271]	validation_0-rmse:248.12268
# [272]	validation_0-rmse:248.10638
# [273]	validation_0-rmse:248.09723
# [274]	validation_0-rmse:248.12231
# [275]	validation_0-rmse:248.19983
# [276]	validation_0-rmse:248.17647
# [277]	validation_0-rmse:248.18843
# [278]	validation_0-rmse:248.20618
# [279]	validation_0-rmse:248.16698
# [280]	validation_0-rmse:248.30701
# [281]	validation_0-rmse:248.42807
# [282]	validation_0-rmse:248.43610
# [283]	validation_0-rmse:248.45348
# [284]	validation_0-rmse:248.43072
# [285]	validation_0-rmse:248.41734
# [286]	validation_0-rmse:248.42818
# [287]	validation_0-rmse:248.44789
# [288]	validation_0-rmse:248.41019
# [289]	validation_0-rmse:248.40365
# [290]	validation_0-rmse:248.51611
# [291]	validation_0-rmse:248.51376
# [292]	validation_0-rmse:248.53465
# [293]	validation_0-rmse:248.63274
# [294]	validation_0-rmse:248.83694
# [295]	validation_0-rmse:248.86479
# [296]	validation_0-rmse:248.84503
# [297]	validation_0-rmse:248.89877
# [298]	validation_0-rmse:248.89618
# [299]	validation_0-rmse:248.96831
# [300]	validation_0-rmse:249.01276
# [301]	validation_0-rmse:248.95191
# [302]	validation_0-rmse:248.85154
# [303]	validation_0-rmse:248.95456
# [304]	validation_0-rmse:248.95593
# [305]	validation_0-rmse:249.08940
# [306]	validation_0-rmse:249.01994
# [307]	validation_0-rmse:249.03090
# [308]	validation_0-rmse:249.07149
# [309]	validation_0-rmse:249.09062
# [310]	validation_0-rmse:249.06750
# [311]	validation_0-rmse:249.04429
# [312]	validation_0-rmse:249.04462
# [313]	validation_0-rmse:249.06912
# [314]	validation_0-rmse:249.11028
# [315]	validation_0-rmse:249.17277
# [316]	validation_0-rmse:249.17356
# [317]	validation_0-rmse:249.23887
# [318]	validation_0-rmse:249.20429
# [319]	validation_0-rmse:249.39841
# [320]	validation_0-rmse:249.39363
# [321]	validation_0-rmse:249.35839
# [322]	validation_0-rmse:249.37622
# [323]	validation_0-rmse:249.38469
# [324]	validation_0-rmse:249.51700
# [325]	validation_0-rmse:249.50941
# [326]	validation_0-rmse:249.42003
# [327]	validation_0-rmse:249.57082
# [328]	validation_0-rmse:249.54103
# [329]	validation_0-rmse:249.56791
# [330]	validation_0-rmse:249.57398
# [331]	validation_0-rmse:249.60064
# [332]	validation_0-rmse:249.54127
# [333]	validation_0-rmse:249.54823
# [334]	validation_0-rmse:249.51712
# [335]	validation_0-rmse:249.78177
# [336]	validation_0-rmse:249.84220
# [337]	validation_0-rmse:249.89141
# [338]	validation_0-rmse:249.96095
# [339]	validation_0-rmse:249.96071
# [340]	validation_0-rmse:249.93143
# [341]	validation_0-rmse:249.95528
# [342]	validation_0-rmse:250.01929
# [343]	validation_0-rmse:250.05610
# [344]	validation_0-rmse:250.06225
# [345]	validation_0-rmse:250.07538
# [346]	validation_0-rmse:250.07637
# [347]	validation_0-rmse:250.07046
# [348]	validation_0-rmse:250.12569
# [349]	validation_0-rmse:250.05066
# [350]	validation_0-rmse:250.21548
# [351]	validation_0-rmse:250.24099
# [352]	validation_0-rmse:250.24574
# [353]	validation_0-rmse:250.23218
# [354]	validation_0-rmse:250.29438
# [355]	validation_0-rmse:250.32637
# [356]	validation_0-rmse:250.30928
# [357]	validation_0-rmse:250.31400
# [358]	validation_0-rmse:250.31201
# [359]	validation_0-rmse:250.32588
# [360]	validation_0-rmse:250.38850
# [361]	validation_0-rmse:250.38212
# [362]	validation_0-rmse:250.41006
# [363]	validation_0-rmse:250.41140
# [364]	validation_0-rmse:250.61114
# [365]	validation_0-rmse:250.62270
# [366]	validation_0-rmse:250.65373
# [367]	validation_0-rmse:250.71486
# [368]	validation_0-rmse:250.74686
# [369]	validation_0-rmse:250.72443
# [370]	validation_0-rmse:250.70161
# [371]	validation_0-rmse:250.74664
# [372]	validation_0-rmse:250.81119
# [373]	validation_0-rmse:250.81613
# [374]	validation_0-rmse:250.79400
# [375]	validation_0-rmse:250.82676
# [376]	validation_0-rmse:250.90250
# [377]	validation_0-rmse:250.89838
# [378]	validation_0-rmse:250.89875
# [379]	validation_0-rmse:251.02714
# [380]	validation_0-rmse:251.02483
# [381]	validation_0-rmse:251.07222
# [382]	validation_0-rmse:251.04321
# [383]	validation_0-rmse:251.06824
# [384]	validation_0-rmse:251.10070
# [385]	validation_0-rmse:251.13726
# [386]	validation_0-rmse:251.19713
# [387]	validation_0-rmse:251.19732
# [388]	validation_0-rmse:251.18477
# [389]	validation_0-rmse:251.18560
# [390]	validation_0-rmse:251.21707
# [391]	validation_0-rmse:251.23180
# [392]	validation_0-rmse:251.22297
# [393]	validation_0-rmse:251.14200
# [394]	validation_0-rmse:251.14685
# [395]	validation_0-rmse:251.13945
# [396]	validation_0-rmse:251.15522
# [397]	validation_0-rmse:251.19300
# [398]	validation_0-rmse:251.21307
# [399]	validation_0-rmse:251.12295
# [400]	validation_0-rmse:251.13473
# [401]	validation_0-rmse:251.13381
# [402]	validation_0-rmse:251.14797
# [403]	validation_0-rmse:251.15838
# [404]	validation_0-rmse:251.19538
# [405]	validation_0-rmse:251.20526
# [406]	validation_0-rmse:251.30852
# [407]	validation_0-rmse:251.36443
# [408]	validation_0-rmse:251.35708
# [409]	validation_0-rmse:251.35082
# [410]	validation_0-rmse:251.37069
# [411]	validation_0-rmse:251.35669
# [412]	validation_0-rmse:251.29507
# [413]	validation_0-rmse:251.35182
# [414]	validation_0-rmse:251.38180
# [415]	validation_0-rmse:251.39510
# [416]	validation_0-rmse:251.42119
# [417]	validation_0-rmse:251.41322
# [418]	validation_0-rmse:251.40202
# [419]	validation_0-rmse:251.40422
# [420]	validation_0-rmse:251.44339
# [421]	validation_0-rmse:251.48876
# [422]	validation_0-rmse:251.48825
# [423]	validation_0-rmse:251.56588
# [424]	validation_0-rmse:251.65712
# [425]	validation_0-rmse:251.65110
# [426]	validation_0-rmse:251.63674
# [427]	validation_0-rmse:251.74593
# [428]	validation_0-rmse:251.67257
# [429]	validation_0-rmse:251.70382
# [430]	validation_0-rmse:251.66415
# [431]	validation_0-rmse:251.75294
# [432]	validation_0-rmse:251.76101
# [433]	validation_0-rmse:251.72440
# [434]	validation_0-rmse:251.68103
# [435]	validation_0-rmse:251.66961
# [436]	validation_0-rmse:251.70178
# [437]	validation_0-rmse:251.72587
# [438]	validation_0-rmse:251.78272
# [439]	validation_0-rmse:251.84325
# [440]	validation_0-rmse:251.87034
# [441]	validation_0-rmse:251.93771
# [442]	validation_0-rmse:251.95830
# [443]	validation_0-rmse:252.01292
# [444]	validation_0-rmse:252.01290
# [445]	validation_0-rmse:252.04749
# [446]	validation_0-rmse:252.05506
# [447]	validation_0-rmse:252.07287
# [448]	validation_0-rmse:252.10592
# [449]	validation_0-rmse:252.11974
# [450]	validation_0-rmse:252.15465
# [451]	validation_0-rmse:252.18483
# [452]	validation_0-rmse:252.18703
# [453]	validation_0-rmse:252.20169
# [454]	validation_0-rmse:252.19913
# [455]	validation_0-rmse:252.25907
# [456]	validation_0-rmse:252.22729
# [457]	validation_0-rmse:252.22641
# [458]	validation_0-rmse:252.23924
# [459]	validation_0-rmse:252.23035
# [460]	validation_0-rmse:252.25110
# [461]	validation_0-rmse:252.25254
# [462]	validation_0-rmse:252.24740
# [463]	validation_0-rmse:252.25722
# [464]	validation_0-rmse:252.31394
# [465]	validation_0-rmse:252.32883
# [466]	validation_0-rmse:252.32213
# [467]	validation_0-rmse:252.30493
# [468]	validation_0-rmse:252.21395
# [469]	validation_0-rmse:252.21544
# [470]	validation_0-rmse:252.27351
# [471]	validation_0-rmse:252.32064
# [472]	validation_0-rmse:252.36123
# [473]	validation_0-rmse:252.26745
# [474]	validation_0-rmse:252.26845
# [475]	validation_0-rmse:252.29615
# [476]	validation_0-rmse:252.23739
# [477]	validation_0-rmse:252.24324
# [478]	validation_0-rmse:252.25000
# [479]	validation_0-rmse:252.30491
# [480]	validation_0-rmse:252.28109
# [481]	validation_0-rmse:252.30103
# [482]	validation_0-rmse:252.27974
# [483]	validation_0-rmse:252.28374
# [484]	validation_0-rmse:252.27531
# [485]	validation_0-rmse:252.32754
# [486]	validation_0-rmse:252.40609
# [487]	validation_0-rmse:252.41551
# [488]	validation_0-rmse:252.40949
# [489]	validation_0-rmse:252.41051
# [490]	validation_0-rmse:252.60008
# [491]	validation_0-rmse:252.56386
# [492]	validation_0-rmse:252.56737
# [493]	validation_0-rmse:252.55992
# [494]	validation_0-rmse:252.48687
# [495]	validation_0-rmse:252.48559
# [496]	validation_0-rmse:252.43425
# [497]	validation_0-rmse:252.46706
# [498]	validation_0-rmse:252.49256
# [499]	validation_0-rmse:252.52756
# [500]	validation_0-rmse:252.56141
# [501]	validation_0-rmse:252.54896
# [502]	validation_0-rmse:252.54994
# [503]	validation_0-rmse:252.55426
# [504]	validation_0-rmse:252.45935
# [505]	validation_0-rmse:252.46703
# [506]	validation_0-rmse:252.45784
# [507]	validation_0-rmse:252.47598
# [508]	validation_0-rmse:252.48908
# [509]	validation_0-rmse:252.50351
# [510]	validation_0-rmse:252.50166
# [511]	validation_0-rmse:252.53403
# [512]	validation_0-rmse:252.52915
# [513]	validation_0-rmse:252.55743
# [514]	validation_0-rmse:252.67808
# [515]	validation_0-rmse:252.63498
# [516]	validation_0-rmse:252.67086
# [517]	validation_0-rmse:252.67238
# [518]	validation_0-rmse:252.69722
# [519]	validation_0-rmse:252.69688
# [520]	validation_0-rmse:252.74153
# [521]	validation_0-rmse:252.80328
# [522]	validation_0-rmse:252.83018
# [523]	validation_0-rmse:252.84943
# [524]	validation_0-rmse:252.86676
# [525]	validation_0-rmse:252.93621
# [526]	validation_0-rmse:252.90635
# [527]	validation_0-rmse:252.90857
# [528]	validation_0-rmse:252.91032
# [529]	validation_0-rmse:252.91127
# [530]	validation_0-rmse:252.90783
# [531]	validation_0-rmse:252.93662
# [532]	validation_0-rmse:252.89030
# [533]	validation_0-rmse:252.96355
# [534]	validation_0-rmse:252.96089
# [535]	validation_0-rmse:252.96180
# [536]	validation_0-rmse:253.00113
# [537]	validation_0-rmse:253.01581
# [538]	validation_0-rmse:253.00967
# [539]	validation_0-rmse:253.08156
# [540]	validation_0-rmse:253.09286
# [541]	validation_0-rmse:253.11396
# [542]	validation_0-rmse:253.05483
# [543]	validation_0-rmse:253.05210
# [544]	validation_0-rmse:252.98496
# [545]	validation_0-rmse:252.96697
# [546]	validation_0-rmse:252.98431
# [547]	validation_0-rmse:252.97855
# [548]	validation_0-rmse:253.00482
# [549]	validation_0-rmse:252.96139
# [550]	validation_0-rmse:252.96233
# [551]	validation_0-rmse:252.90161
# [552]	validation_0-rmse:252.90153
# [553]	validation_0-rmse:252.87066
# [554]	validation_0-rmse:252.92983
# [555]	validation_0-rmse:252.93479
# [556]	validation_0-rmse:252.93594
# [557]	validation_0-rmse:252.95014
# [558]	validation_0-rmse:252.94476
# [559]	validation_0-rmse:252.81758
# [560]	validation_0-rmse:252.68608
# [561]	validation_0-rmse:252.68797
# [562]	validation_0-rmse:252.69238
# [563]	validation_0-rmse:252.67345
# [564]	validation_0-rmse:252.70029
# [565]	validation_0-rmse:252.68235
# [566]	validation_0-rmse:252.67823
# [567]	validation_0-rmse:252.67455
# [568]	validation_0-rmse:252.68931
# [569]	validation_0-rmse:252.67269
# [570]	validation_0-rmse:252.68310
# [571]	validation_0-rmse:252.66371
# [572]	validation_0-rmse:252.65344
# [573]	validation_0-rmse:252.64168
# [574]	validation_0-rmse:252.68030
# [575]	validation_0-rmse:252.75552
# [576]	validation_0-rmse:252.76381
# [577]	validation_0-rmse:252.77550
# [578]	validation_0-rmse:252.79019
# [579]	validation_0-rmse:252.81205
# [580]	validation_0-rmse:252.83827
# [581]	validation_0-rmse:252.95101
# [582]	validation_0-rmse:252.91341
# [583]	validation_0-rmse:252.90747
# [584]	validation_0-rmse:252.87499
# [585]	validation_0-rmse:252.87333
# [586]	validation_0-rmse:252.92793
# [587]	validation_0-rmse:252.94561
# [588]	validation_0-rmse:252.96443
# [589]	validation_0-rmse:252.97627
# [590]	validation_0-rmse:252.97828
# [591]	validation_0-rmse:252.98437
# [592]	validation_0-rmse:252.97686
# [593]	validation_0-rmse:252.98307
# [594]	validation_0-rmse:252.98659
# [595]	validation_0-rmse:252.97617
# [596]	validation_0-rmse:252.96745
# [597]	validation_0-rmse:252.98255
# [598]	validation_0-rmse:252.97501
# [599]	validation_0-rmse:252.99066
# [600]	validation_0-rmse:252.97522
# [601]	validation_0-rmse:252.94011
# [602]	validation_0-rmse:252.86786
# [603]	validation_0-rmse:252.87199
# [604]	validation_0-rmse:252.86971
# [605]	validation_0-rmse:252.84313
# [606]	validation_0-rmse:252.85615
# [607]	validation_0-rmse:252.85904
# [608]	validation_0-rmse:252.88075
# [609]	validation_0-rmse:252.87779
# [610]	validation_0-rmse:252.88504
# [611]	validation_0-rmse:252.94046
# [612]	validation_0-rmse:252.94381
# [613]	validation_0-rmse:252.93900
# [614]	validation_0-rmse:253.05631
# [615]	validation_0-rmse:253.14427
# [616]	validation_0-rmse:253.12872
# [617]	validation_0-rmse:253.12802
# [618]	validation_0-rmse:253.20620
# [619]	validation_0-rmse:253.24198
# [620]	validation_0-rmse:253.26429
# [621]	validation_0-rmse:253.24947
# [622]	validation_0-rmse:253.20242
# [623]	validation_0-rmse:253.23599
# [624]	validation_0-rmse:253.22636
# [625]	validation_0-rmse:253.22424
# [626]	validation_0-rmse:253.20845
# [627]	validation_0-rmse:253.21579
# [628]	validation_0-rmse:253.25662
# [629]	validation_0-rmse:253.24760
# [630]	validation_0-rmse:253.28888
# [631]	validation_0-rmse:253.28420
# [632]	validation_0-rmse:253.26942
# [633]	validation_0-rmse:253.30249
# [634]	validation_0-rmse:253.32211
# [635]	validation_0-rmse:253.33325
# [636]	validation_0-rmse:253.34774
# [637]	validation_0-rmse:253.35031
# [638]	validation_0-rmse:253.27606
# [639]	validation_0-rmse:253.27098
# [640]	validation_0-rmse:253.26613
# [641]	validation_0-rmse:253.25769
# [642]	validation_0-rmse:253.26514
# [643]	validation_0-rmse:253.27662
# [644]	validation_0-rmse:253.27767
# [645]	validation_0-rmse:253.28760
# [646]	validation_0-rmse:253.27715
# [647]	validation_0-rmse:253.27966
# [648]	validation_0-rmse:253.28898
# [649]	validation_0-rmse:253.31971
# [650]	validation_0-rmse:253.37038
# [651]	validation_0-rmse:253.34604
# [652]	validation_0-rmse:253.37131
# [653]	validation_0-rmse:253.36449
# [654]	validation_0-rmse:253.38060
# [655]	validation_0-rmse:253.40641
# [656]	validation_0-rmse:253.42607
# [657]	validation_0-rmse:253.40174
# [658]	validation_0-rmse:253.37850
# [659]	validation_0-rmse:253.37678
# [660]	validation_0-rmse:253.58207
# [661]	validation_0-rmse:253.59717
# [662]	validation_0-rmse:253.59298
# [663]	validation_0-rmse:253.58716
# [664]	validation_0-rmse:253.62137
# [665]	validation_0-rmse:253.62891
# [666]	validation_0-rmse:253.62535
# [667]	validation_0-rmse:253.61154
# [668]	validation_0-rmse:253.62851
# [669]	validation_0-rmse:253.62017
# [670]	validation_0-rmse:253.62636
# [671]	validation_0-rmse:253.62791
# [672]	validation_0-rmse:253.50508
# [673]	validation_0-rmse:253.52918
# [674]	validation_0-rmse:253.56621
# [675]	validation_0-rmse:253.56671
# [676]	validation_0-rmse:253.57615
# [677]	validation_0-rmse:253.56050
# [678]	validation_0-rmse:253.77689
# [679]	validation_0-rmse:253.72177
# [680]	validation_0-rmse:253.72238
# [681]	validation_0-rmse:253.60662
# [682]	validation_0-rmse:253.63790
# [683]	validation_0-rmse:253.63833
# [684]	validation_0-rmse:253.67008
# [685]	validation_0-rmse:253.70004
# [686]	validation_0-rmse:253.77582
# [687]	validation_0-rmse:253.80105
# [688]	validation_0-rmse:253.80092
# [689]	validation_0-rmse:253.79533
# [690]	validation_0-rmse:253.78915
# [691]	validation_0-rmse:253.69455
# [692]	validation_0-rmse:253.71649
# [693]	validation_0-rmse:253.75427
# [694]	validation_0-rmse:253.75150
# [695]	validation_0-rmse:253.70684
# [696]	validation_0-rmse:253.69678
# [697]	validation_0-rmse:253.67455
# [698]	validation_0-rmse:253.68734
# [699]	validation_0-rmse:253.68832
# [700]	validation_0-rmse:253.69100
# [701]	validation_0-rmse:253.67974
# [702]	validation_0-rmse:253.66089
# [703]	validation_0-rmse:253.63747
# [704]	validation_0-rmse:253.63730
# [705]	validation_0-rmse:253.69032
# [706]	validation_0-rmse:253.70282
# [707]	validation_0-rmse:253.72050
# [708]	validation_0-rmse:253.73858
# [709]	validation_0-rmse:253.75729
# [710]	validation_0-rmse:253.76481
# [711]	validation_0-rmse:253.84164
# [712]	validation_0-rmse:253.83999
# [713]	validation_0-rmse:253.83967
# [714]	validation_0-rmse:253.85572
# [715]	validation_0-rmse:253.89267
# [716]	validation_0-rmse:253.98621
# [717]	validation_0-rmse:254.01155
# [718]	validation_0-rmse:254.06080
# [719]	validation_0-rmse:254.04010
# [720]	validation_0-rmse:254.03129
# [721]	validation_0-rmse:254.01864
# [722]	validation_0-rmse:254.02591
# [723]	validation_0-rmse:254.03899
# [724]	validation_0-rmse:254.04716
# [725]	validation_0-rmse:254.06304
# [726]	validation_0-rmse:254.04730
# [727]	validation_0-rmse:254.04354
# [728]	validation_0-rmse:254.03854
# [729]	validation_0-rmse:254.05916
# [730]	validation_0-rmse:254.05532
# [731]	validation_0-rmse:254.06401
# [732]	validation_0-rmse:254.08796
# [733]	validation_0-rmse:254.07475
# [734]	validation_0-rmse:254.10747
# [735]	validation_0-rmse:254.12038
# [736]	validation_0-rmse:254.11006
# [737]	validation_0-rmse:254.09348
# [738]	validation_0-rmse:254.09974
# [739]	validation_0-rmse:254.13847
# [740]	validation_0-rmse:254.15756
# [741]	validation_0-rmse:254.15498
# [742]	validation_0-rmse:254.15015
# [743]	validation_0-rmse:254.15444
# [744]	validation_0-rmse:254.16348
# [745]	validation_0-rmse:254.17154
# [746]	validation_0-rmse:254.16601
# [747]	validation_0-rmse:254.16938
# [748]	validation_0-rmse:254.17513
# [749]	validation_0-rmse:254.19094
# [750]	validation_0-rmse:254.10163
# [751]	validation_0-rmse:254.12283
# [752]	validation_0-rmse:254.13091
# [753]	validation_0-rmse:254.12034
# [754]	validation_0-rmse:254.10883
# [755]	validation_0-rmse:254.08400
# [756]	validation_0-rmse:254.07532
# [757]	validation_0-rmse:254.05908
# [758]	validation_0-rmse:254.05706
# [759]	validation_0-rmse:254.06801
# [760]	validation_0-rmse:254.06701
# [761]	validation_0-rmse:254.08200
# [762]	validation_0-rmse:254.13537
# [763]	validation_0-rmse:254.16188
# [764]	validation_0-rmse:254.15631
# [765]	validation_0-rmse:254.15618
# [766]	validation_0-rmse:254.16422
# [767]	validation_0-rmse:254.16252
# [768]	validation_0-rmse:254.21234
# [769]	validation_0-rmse:254.21718
# [770]	validation_0-rmse:254.22105
# [771]	validation_0-rmse:254.22452
# [772]	validation_0-rmse:254.22824
# [773]	validation_0-rmse:254.23447
# [774]	validation_0-rmse:254.22881
# [775]	validation_0-rmse:254.32113
# [776]	validation_0-rmse:254.31197
# [777]	validation_0-rmse:254.33518
# [778]	validation_0-rmse:254.28654
# [779]	validation_0-rmse:254.27796
# [780]	validation_0-rmse:254.27745
# [781]	validation_0-rmse:254.33630
# [782]	validation_0-rmse:254.33926
# [783]	validation_0-rmse:254.32283
# [784]	validation_0-rmse:254.33490
# [785]	validation_0-rmse:254.34033
# [786]	validation_0-rmse:254.34658
# [787]	validation_0-rmse:254.33966
# [788]	validation_0-rmse:254.36034
# [789]	validation_0-rmse:254.29582
# [790]	validation_0-rmse:254.27614
# [791]	validation_0-rmse:254.26112
# [792]	validation_0-rmse:254.29638
# [793]	validation_0-rmse:254.30869
# [794]	validation_0-rmse:254.29521
# [795]	validation_0-rmse:254.30376
# [796]	validation_0-rmse:254.29722
# [797]	validation_0-rmse:254.29468
# [798]	validation_0-rmse:254.28930
# [799]	validation_0-rmse:254.27231
# [800]	validation_0-rmse:254.27266
# [801]	validation_0-rmse:254.14588
# [802]	validation_0-rmse:254.16152
# [803]	validation_0-rmse:254.14252
# [804]	validation_0-rmse:254.13305
# [805]	validation_0-rmse:254.13289
# [806]	validation_0-rmse:254.11424
# [807]	validation_0-rmse:254.12191
# [808]	validation_0-rmse:254.12642
# [809]	validation_0-rmse:254.14323
# [810]	validation_0-rmse:254.13980
# [811]	validation_0-rmse:254.12164
# [812]	validation_0-rmse:254.12639
# [813]	validation_0-rmse:254.15158
# [814]	validation_0-rmse:254.14851
# [815]	validation_0-rmse:254.20127
# [816]	validation_0-rmse:254.20543
# [817]	validation_0-rmse:254.21393
# [818]	validation_0-rmse:254.21352
# [819]	validation_0-rmse:254.22485
# [820]	validation_0-rmse:254.20379
# [821]	validation_0-rmse:254.21746
# [822]	validation_0-rmse:254.23464
# [823]	validation_0-rmse:254.25831
# [824]	validation_0-rmse:254.28399
# [825]	validation_0-rmse:254.25082
# [826]	validation_0-rmse:254.24898
# [827]	validation_0-rmse:254.26454
# [828]	validation_0-rmse:254.25197
# [829]	validation_0-rmse:254.24669
# [830]	validation_0-rmse:254.24595
# [831]	validation_0-rmse:254.24508
# [832]	validation_0-rmse:254.27055
# [833]	validation_0-rmse:254.26902
# [834]	validation_0-rmse:254.23666
# [835]	validation_0-rmse:254.25783
# [836]	validation_0-rmse:254.25794
# [837]	validation_0-rmse:254.24103
# [838]	validation_0-rmse:254.24792
# [839]	validation_0-rmse:254.25068
# [840]	validation_0-rmse:254.25914
# [841]	validation_0-rmse:254.27650
# [842]	validation_0-rmse:254.27937
# [843]	validation_0-rmse:254.27390
# [844]	validation_0-rmse:254.29581
# [845]	validation_0-rmse:254.29629
# [846]	validation_0-rmse:254.30235
# [847]	validation_0-rmse:254.29664
# [848]	validation_0-rmse:254.32398
# [849]	validation_0-rmse:254.32967
# [850]	validation_0-rmse:254.33855
# [851]	validation_0-rmse:254.34247
# [852]	validation_0-rmse:254.33143
# [853]	validation_0-rmse:254.41768
# [854]	validation_0-rmse:254.40353
# [855]	validation_0-rmse:254.40462
# [856]	validation_0-rmse:254.41097
# [857]	validation_0-rmse:254.43178
# [858]	validation_0-rmse:254.42057
# [859]	validation_0-rmse:254.42688
# [860]	validation_0-rmse:254.41961
# [861]	validation_0-rmse:254.43275
# [862]	validation_0-rmse:254.44294
# [863]	validation_0-rmse:254.47819
# [864]	validation_0-rmse:254.48611
# [865]	validation_0-rmse:254.48412
# [866]	validation_0-rmse:254.47231
# [867]	validation_0-rmse:254.44692
# [868]	validation_0-rmse:254.45349
# [869]	validation_0-rmse:254.44834
# [870]	validation_0-rmse:254.44868
# [871]	validation_0-rmse:254.44834
# [872]	validation_0-rmse:254.45274
# [873]	validation_0-rmse:254.44240
# [874]	validation_0-rmse:254.46962
# [875]	validation_0-rmse:254.48400
# [876]	validation_0-rmse:254.47569
# [877]	validation_0-rmse:254.45979
# [878]	validation_0-rmse:254.46419
# [879]	validation_0-rmse:254.48608
# [880]	validation_0-rmse:254.47128
# [881]	validation_0-rmse:254.46930
# [882]	validation_0-rmse:254.47715
# [883]	validation_0-rmse:254.49389
# [884]	validation_0-rmse:254.54404
# [885]	validation_0-rmse:254.55407
# [886]	validation_0-rmse:254.56328
# [887]	validation_0-rmse:254.55167
# [888]	validation_0-rmse:254.54729
# [889]	validation_0-rmse:254.50971
# [890]	validation_0-rmse:254.55684
# [891]	validation_0-rmse:254.55187
# [892]	validation_0-rmse:254.57436
# [893]	validation_0-rmse:254.57020
# [894]	validation_0-rmse:254.57714
# [895]	validation_0-rmse:254.58242
# [896]	validation_0-rmse:254.58532
# [897]	validation_0-rmse:254.60861
# [898]	validation_0-rmse:254.61888
# [899]	validation_0-rmse:254.60915
# [900]	validation_0-rmse:254.59883
# [901]	validation_0-rmse:254.60081
# [902]	validation_0-rmse:254.62075
# [903]	validation_0-rmse:254.62953
# [904]	validation_0-rmse:254.62204
# [905]	validation_0-rmse:254.60661
# [906]	validation_0-rmse:254.60688
# [907]	validation_0-rmse:254.62884
# [908]	validation_0-rmse:254.63486
# [909]	validation_0-rmse:254.64638
# [910]	validation_0-rmse:254.63922
# [911]	validation_0-rmse:254.65725
# [912]	validation_0-rmse:254.64861
# [913]	validation_0-rmse:254.64160
# [914]	validation_0-rmse:254.64329
# [915]	validation_0-rmse:254.63532
# [916]	validation_0-rmse:254.63018
# [917]	validation_0-rmse:254.62875
# [918]	validation_0-rmse:254.61113
# [919]	validation_0-rmse:254.60900
# [920]	validation_0-rmse:254.62973
# [921]	validation_0-rmse:254.64482
# [922]	validation_0-rmse:254.68055
# [923]	validation_0-rmse:254.68438
# [924]	validation_0-rmse:254.75287
# [925]	validation_0-rmse:254.72871
# [926]	validation_0-rmse:254.70814
# [927]	validation_0-rmse:254.70651
# [928]	validation_0-rmse:254.70206
# [929]	validation_0-rmse:254.69837
# [930]	validation_0-rmse:254.70664
# [931]	validation_0-rmse:254.71266
# [932]	validation_0-rmse:254.74766
# [933]	validation_0-rmse:254.71554
# [934]	validation_0-rmse:254.74459
# [935]	validation_0-rmse:254.73726
# [936]	validation_0-rmse:254.74186
# [937]	validation_0-rmse:254.71550
# [938]	validation_0-rmse:254.71422
# [939]	validation_0-rmse:254.71976
# [940]	validation_0-rmse:254.73221
# [941]	validation_0-rmse:254.76565
# [942]	validation_0-rmse:254.76150
# [943]	validation_0-rmse:254.78255
# [944]	validation_0-rmse:254.76692
# [945]	validation_0-rmse:254.78382
# [946]	validation_0-rmse:254.78041
# [947]	validation_0-rmse:254.78548
# [948]	validation_0-rmse:254.75367
# [949]	validation_0-rmse:254.76262
# [950]	validation_0-rmse:254.79119
# [951]	validation_0-rmse:254.80136
# [952]	validation_0-rmse:254.80763
# [953]	validation_0-rmse:254.81545
# [954]	validation_0-rmse:254.82158
# [955]	validation_0-rmse:254.89584
# [956]	validation_0-rmse:254.89714
# [957]	validation_0-rmse:254.91080
# [958]	validation_0-rmse:255.02319
# [959]	validation_0-rmse:255.01906
# [960]	validation_0-rmse:255.01432
# [961]	validation_0-rmse:255.04159
# [962]	validation_0-rmse:255.04132
# [963]	validation_0-rmse:255.01640
# [964]	validation_0-rmse:255.03053
# [965]	validation_0-rmse:255.05952
# [966]	validation_0-rmse:255.06482
# [967]	validation_0-rmse:255.08116
# [968]	validation_0-rmse:255.07913
# [969]	validation_0-rmse:255.08310
# [970]	validation_0-rmse:255.09059
# [971]	validation_0-rmse:255.08109
# [972]	validation_0-rmse:255.12335
# [973]	validation_0-rmse:255.11841
# [974]	validation_0-rmse:255.11278
# [975]	validation_0-rmse:255.10398
# [976]	validation_0-rmse:255.11404
# [977]	validation_0-rmse:255.12432
# [978]	validation_0-rmse:255.16633
# [979]	validation_0-rmse:255.18940
# [980]	validation_0-rmse:255.20447
# [981]	validation_0-rmse:255.23947
# [982]	validation_0-rmse:255.19961
# [983]	validation_0-rmse:255.22033
# [984]	validation_0-rmse:255.23105
# [985]	validation_0-rmse:255.23106
# [986]	validation_0-rmse:255.20398
# [987]	validation_0-rmse:255.20082
# [988]	validation_0-rmse:255.19967
# [989]	validation_0-rmse:255.19606
# [990]	validation_0-rmse:255.20601
# [991]	validation_0-rmse:255.22607
# [992]	validation_0-rmse:255.24369
# [993]	validation_0-rmse:255.24258
# [994]	validation_0-rmse:255.25206
# [995]	validation_0-rmse:255.16804
# [996]	validation_0-rmse:255.18418
# [997]	validation_0-rmse:255.17574
# [998]	validation_0-rmse:255.18977
# [999]	validation_0-rmse:255.14325
# [1000]	validation_0-rmse:255.13519
# [1001]	validation_0-rmse:255.10931
# [1002]	validation_0-rmse:255.12883
# [1003]	validation_0-rmse:255.13884
# [1004]	validation_0-rmse:255.12918
# [1005]	validation_0-rmse:255.16115
# [1006]	validation_0-rmse:255.16041
# [1007]	validation_0-rmse:255.16991
# [1008]	validation_0-rmse:255.18988
# [1009]	validation_0-rmse:255.21952
# [1010]	validation_0-rmse:255.23680
# [1011]	validation_0-rmse:255.23382
# [1012]	validation_0-rmse:255.25339
# [1013]	validation_0-rmse:255.24078
# [1014]	validation_0-rmse:255.24252
# [1015]	validation_0-rmse:255.26480
# [1016]	validation_0-rmse:255.28691
# [1017]	validation_0-rmse:255.29146
# [1018]	validation_0-rmse:255.29747
# [1019]	validation_0-rmse:255.31861
# [1020]	validation_0-rmse:255.29952
# [1021]	validation_0-rmse:255.30373
# [1022]	validation_0-rmse:255.33292
# [1023]	validation_0-rmse:255.33158
# [1024]	validation_0-rmse:255.35067
# [1025]	validation_0-rmse:255.35998
# [1026]	validation_0-rmse:255.35183
# [1027]	validation_0-rmse:255.34778
# [1028]	validation_0-rmse:255.34064
# [1029]	validation_0-rmse:255.34831
# [1030]	validation_0-rmse:255.34939
# [1031]	validation_0-rmse:255.36875
# [1032]	validation_0-rmse:255.41742
# [1033]	validation_0-rmse:255.44299
# [1034]	validation_0-rmse:255.46190
# [1035]	validation_0-rmse:255.46426
# [1036]	validation_0-rmse:255.44612
# [1037]	validation_0-rmse:255.47184
# [1038]	validation_0-rmse:255.43343
# [1039]	validation_0-rmse:255.44052
# [1040]	validation_0-rmse:255.44497
# [1041]	validation_0-rmse:255.45753
# [1042]	validation_0-rmse:255.45839
# [1043]	validation_0-rmse:255.44023
# [1044]	validation_0-rmse:255.45558
# [1045]	validation_0-rmse:255.45874
# [1046]	validation_0-rmse:255.44009
# [1047]	validation_0-rmse:255.43906
# [1048]	validation_0-rmse:255.45555
# [1049]	validation_0-rmse:255.45223
# [1050]	validation_0-rmse:255.47990
# [1051]	validation_0-rmse:255.47742
# [1052]	validation_0-rmse:255.48687
# [1053]	validation_0-rmse:255.54287
# [1054]	validation_0-rmse:255.54928
# [1055]	validation_0-rmse:255.55262
# [1056]	validation_0-rmse:255.57417
# [1057]	validation_0-rmse:255.56937
# [1058]	validation_0-rmse:255.56139
# [1059]	validation_0-rmse:255.57048
# [1060]	validation_0-rmse:255.58098
# [1061]	validation_0-rmse:255.57721
# [1062]	validation_0-rmse:255.51630
# [1063]	validation_0-rmse:255.51454
# [1064]	validation_0-rmse:255.51280
# [1065]	validation_0-rmse:255.46082
# [1066]	validation_0-rmse:255.46289
# [1067]	validation_0-rmse:255.45208
# [1068]	validation_0-rmse:255.44880
# [1069]	validation_0-rmse:255.44739
# [1070]	validation_0-rmse:255.45777
# [1071]	validation_0-rmse:255.45626
# [1072]	validation_0-rmse:255.47339
# [1073]	validation_0-rmse:255.46675
# [1074]	validation_0-rmse:255.50684
# [1075]	validation_0-rmse:255.51973
# [1076]	validation_0-rmse:255.52860
# [1077]	validation_0-rmse:255.52393
# [1078]	validation_0-rmse:255.53271
# [1079]	validation_0-rmse:255.52405
# [1080]	validation_0-rmse:255.52011
# [1081]	validation_0-rmse:255.52856
# [1082]	validation_0-rmse:255.53277
# [1083]	validation_0-rmse:255.54177
# [1084]	validation_0-rmse:255.53450
# [1085]	validation_0-rmse:255.54966
# [1086]	validation_0-rmse:255.57511
# [1087]	validation_0-rmse:255.54998
# [1088]	validation_0-rmse:255.55519
# [1089]	validation_0-rmse:255.55806
# [1090]	validation_0-rmse:255.56350
# [1091]	validation_0-rmse:255.56527
# [1092]	validation_0-rmse:255.60677
# [1093]	validation_0-rmse:255.61147
# [1094]	validation_0-rmse:255.61141
# [1095]	validation_0-rmse:255.60999
# [1096]	validation_0-rmse:255.60672
# [1097]	validation_0-rmse:255.61284
# [1098]	validation_0-rmse:255.60623
# [1099]	validation_0-rmse:255.58651
# [1100]	validation_0-rmse:255.59880
# [1101]	validation_0-rmse:255.61977
# [1102]	validation_0-rmse:255.58606
# [1103]	validation_0-rmse:255.60099
# [1104]	validation_0-rmse:255.59910
# [1105]	validation_0-rmse:255.63961
# [1106]	validation_0-rmse:255.62964
# [1107]	validation_0-rmse:255.63551
# [1108]	validation_0-rmse:255.64596
# [1109]	validation_0-rmse:255.65779
# [1110]	validation_0-rmse:255.67158
# [1111]	validation_0-rmse:255.68039
# [1112]	validation_0-rmse:255.73090
# [1113]	validation_0-rmse:255.74057
# [1114]	validation_0-rmse:255.77037
# [1115]	validation_0-rmse:255.77191
# [1116]	validation_0-rmse:255.75215
# [1117]	validation_0-rmse:255.75782
# [1118]	validation_0-rmse:255.76490
# [1119]	validation_0-rmse:255.78344
# [1120]	validation_0-rmse:255.77022
# [1121]	validation_0-rmse:255.76456
# [1122]	validation_0-rmse:255.75880
# [1123]	validation_0-rmse:255.77736
# [1124]	validation_0-rmse:255.79182
# [1125]	validation_0-rmse:255.79329
# [1126]	validation_0-rmse:255.79955
# [1127]	validation_0-rmse:255.81500
# [1128]	validation_0-rmse:255.81565
# [1129]	validation_0-rmse:255.80514
# [1130]	validation_0-rmse:255.81450
# [1131]	validation_0-rmse:255.85250
# [1132]	validation_0-rmse:255.84501
# [1133]	validation_0-rmse:255.80706
# [1134]	validation_0-rmse:255.81687
# [1135]	validation_0-rmse:255.81916
# [1136]	validation_0-rmse:255.84308
# [1137]	validation_0-rmse:255.83636
# [1138]	validation_0-rmse:255.81207
# [1139]	validation_0-rmse:255.84790
# [1140]	validation_0-rmse:255.84024
# [1141]	validation_0-rmse:255.85028
# [1142]	validation_0-rmse:255.86466
# [1143]	validation_0-rmse:255.86467
# [1144]	validation_0-rmse:255.86453
# [1145]	validation_0-rmse:255.86841
# [1146]	validation_0-rmse:255.87295
# [1147]	validation_0-rmse:255.87242
# [1148]	validation_0-rmse:255.88617
# [1149]	validation_0-rmse:255.87928
# [1150]	validation_0-rmse:255.88722
# [1151]	validation_0-rmse:255.91587
# [1152]	validation_0-rmse:255.94040
# [1153]	validation_0-rmse:255.95517
# [1154]	validation_0-rmse:255.97225
# [1155]	validation_0-rmse:255.95804
# [1156]	validation_0-rmse:255.96393
# [1157]	validation_0-rmse:255.96599
# [1158]	validation_0-rmse:255.94111
# [1159]	validation_0-rmse:255.91361
# [1160]	validation_0-rmse:255.91922
# [1161]	validation_0-rmse:255.92918
# [1162]	validation_0-rmse:255.92409
# [1163]	validation_0-rmse:255.92213
# [1164]	validation_0-rmse:255.93675
# [1165]	validation_0-rmse:255.93338
# [1166]	validation_0-rmse:255.95202
# [1167]	validation_0-rmse:255.96830
# [1168]	validation_0-rmse:255.93831
# [1169]	validation_0-rmse:255.94134
# [1170]	validation_0-rmse:255.91115
# [1171]	validation_0-rmse:255.93448
# [1172]	validation_0-rmse:255.93944
# [1173]	validation_0-rmse:255.94874
# [1174]	validation_0-rmse:255.95710
# [1175]	validation_0-rmse:255.95019
# [1176]	validation_0-rmse:255.96879
# [1177]	validation_0-rmse:255.96107
# [1178]	validation_0-rmse:255.96740
# [1179]	validation_0-rmse:255.96043
# [1180]	validation_0-rmse:255.94955
# [1181]	validation_0-rmse:255.94473
# [1182]	validation_0-rmse:255.94458
# [1183]	validation_0-rmse:255.92689
# [1184]	validation_0-rmse:255.93930
# [1185]	validation_0-rmse:255.91831
# [1186]	validation_0-rmse:255.91396
# [1187]	validation_0-rmse:255.91254
# [1188]	validation_0-rmse:255.89081
# [1189]	validation_0-rmse:255.87771
# [1190]	validation_0-rmse:255.87274
# [1191]	validation_0-rmse:255.87733
# [1192]	validation_0-rmse:255.87855
# [1193]	validation_0-rmse:255.89475
# [1194]	validation_0-rmse:255.89844
# [1195]	validation_0-rmse:255.88608
# [1196]	validation_0-rmse:255.91062
# [1197]	validation_0-rmse:255.89457
# [1198]	validation_0-rmse:255.89412
# [1199]	validation_0-rmse:255.89276
# [1200]	validation_0-rmse:255.84845
# [1201]	validation_0-rmse:255.87771
# [1202]	validation_0-rmse:255.89023
# [1203]	validation_0-rmse:255.88051
# [1204]	validation_0-rmse:255.87245
# [1205]	validation_0-rmse:255.89489
# [1206]	validation_0-rmse:255.89367
# [1207]	validation_0-rmse:255.89622
# [1208]	validation_0-rmse:255.89062
# [1209]	validation_0-rmse:255.94785
# [1210]	validation_0-rmse:255.94687
# [1211]	validation_0-rmse:255.95793
# [1212]	validation_0-rmse:255.95513
# [1213]	validation_0-rmse:255.96432
# [1214]	validation_0-rmse:255.95427
# [1215]	validation_0-rmse:255.96415
# [1216]	validation_0-rmse:255.98099
# [1217]	validation_0-rmse:255.98106
# [1218]	validation_0-rmse:255.97657
# [1219]	validation_0-rmse:255.95983
# [1220]	validation_0-rmse:256.00866
# [1221]	validation_0-rmse:256.01243
# [1222]	validation_0-rmse:256.01126
# [1223]	validation_0-rmse:256.03225
# [1224]	validation_0-rmse:256.04274
# [1225]	validation_0-rmse:256.04572
# [1226]	validation_0-rmse:256.03881
# [1227]	validation_0-rmse:256.03465
# [1228]	validation_0-rmse:256.04541
# [1229]	validation_0-rmse:256.06291
# [1230]	validation_0-rmse:256.07896
# [1231]	validation_0-rmse:256.09141
# [1232]	validation_0-rmse:256.05252
# [1233]	validation_0-rmse:256.05173
# [1234]	validation_0-rmse:256.07246
# [1235]	validation_0-rmse:256.05648
# [1236]	validation_0-rmse:256.04344
# [1237]	validation_0-rmse:256.02450
# [1238]	validation_0-rmse:256.01827
# [1239]	validation_0-rmse:256.02062
# [1240]	validation_0-rmse:256.00291
# [1241]	validation_0-rmse:255.99979
# [1242]	validation_0-rmse:256.03751
# [1243]	validation_0-rmse:256.04019
# [1244]	validation_0-rmse:256.03740
# [1245]	validation_0-rmse:256.05191
# [1246]	validation_0-rmse:256.06062
# [1247]	validation_0-rmse:256.16005
# [1248]	validation_0-rmse:256.16650
# [1249]	validation_0-rmse:256.15155
# [1250]	validation_0-rmse:256.15277
# [1251]	validation_0-rmse:256.17274
# [1252]	validation_0-rmse:256.17676
# [1253]	validation_0-rmse:256.17932
# [1254]	validation_0-rmse:256.18864
# [1255]	validation_0-rmse:256.20149
# [1256]	validation_0-rmse:256.19998
# [1257]	validation_0-rmse:256.20964
# [1258]	validation_0-rmse:256.21700
# [1259]	validation_0-rmse:256.22032
# [1260]	validation_0-rmse:256.20644
# [1261]	validation_0-rmse:256.24456
# [1262]	validation_0-rmse:256.23852
# [1263]	validation_0-rmse:256.24102
# [1264]	validation_0-rmse:256.24173
# [1265]	validation_0-rmse:256.24122
# [1266]	validation_0-rmse:256.23352
# [1267]	validation_0-rmse:256.24983
# [1268]	validation_0-rmse:256.19839
# [1269]	validation_0-rmse:256.18833
# [1270]	validation_0-rmse:256.18488
# [1271]	validation_0-rmse:256.18926
# [1272]	validation_0-rmse:256.18229
# [1273]	validation_0-rmse:256.18535
# [1274]	validation_0-rmse:256.21942
# [1275]	validation_0-rmse:256.21715
# [1276]	validation_0-rmse:256.21095
# [1277]	validation_0-rmse:256.21852
# [1278]	validation_0-rmse:256.23931
# [1279]	validation_0-rmse:256.24964
# [1280]	validation_0-rmse:256.26828
# [1281]	validation_0-rmse:256.26801
# [1282]	validation_0-rmse:256.27423
# [1283]	validation_0-rmse:256.24624
# [1284]	validation_0-rmse:256.21819
# [1285]	validation_0-rmse:256.22391
# [1286]	validation_0-rmse:256.22598
# [1287]	validation_0-rmse:256.22738
# [1288]	validation_0-rmse:256.21096
# [1289]	validation_0-rmse:256.17873
# [1290]	validation_0-rmse:256.19471
# [1291]	validation_0-rmse:256.19094
# [1292]	validation_0-rmse:256.19212
# [1293]	validation_0-rmse:256.18538
# [1294]	validation_0-rmse:256.21519
# [1295]	validation_0-rmse:256.21141
# [1296]	validation_0-rmse:256.20965
# [1297]	validation_0-rmse:256.23665
# [1298]	validation_0-rmse:256.22602
# [1299]	validation_0-rmse:256.22184
# [1300]	validation_0-rmse:256.21781
# [1301]	validation_0-rmse:256.19507
# [1302]	validation_0-rmse:256.19416
# [1303]	validation_0-rmse:256.19818
# [1304]	validation_0-rmse:256.20952
# [1305]	validation_0-rmse:256.21081
# [1306]	validation_0-rmse:256.20599
# [1307]	validation_0-rmse:256.21999
# [1308]	validation_0-rmse:256.19728
# [1309]	validation_0-rmse:256.19170
# [1310]	validation_0-rmse:256.20638
# [1311]	validation_0-rmse:256.20648
# [1312]	validation_0-rmse:256.19796
# [1313]	validation_0-rmse:256.19964
# [1314]	validation_0-rmse:256.20919
# [1315]	validation_0-rmse:256.20872
# [1316]	validation_0-rmse:256.21378
# [1317]	validation_0-rmse:256.20638
# [1318]	validation_0-rmse:256.21408
# [1319]	validation_0-rmse:256.23179
# [1320]	validation_0-rmse:256.23416
# [1321]	validation_0-rmse:256.25179
# [1322]	validation_0-rmse:256.26825
# [1323]	validation_0-rmse:256.26548
# [1324]	validation_0-rmse:256.26414
# [1325]	validation_0-rmse:256.28325
# [1326]	validation_0-rmse:256.28269
# [1327]	validation_0-rmse:256.28795
# [1328]	validation_0-rmse:256.29284
# [1329]	validation_0-rmse:256.28431
# [1330]	validation_0-rmse:256.29198
# [1331]	validation_0-rmse:256.31379
# [1332]	validation_0-rmse:256.31722
# [1333]	validation_0-rmse:256.30342
# [1334]	validation_0-rmse:256.31555
# [1335]	validation_0-rmse:256.31915
# [1336]	validation_0-rmse:256.31143
# [1337]	validation_0-rmse:256.32769
# [1338]	validation_0-rmse:256.30977
# [1339]	validation_0-rmse:256.30345
# [1340]	validation_0-rmse:256.30111
# [1341]	validation_0-rmse:256.31051
# [1342]	validation_0-rmse:256.32454
# [1343]	validation_0-rmse:256.34765
# [1344]	validation_0-rmse:256.34526
# [1345]	validation_0-rmse:256.32334
# [1346]	validation_0-rmse:256.33831
# [1347]	validation_0-rmse:256.33884
# [1348]	validation_0-rmse:256.36452
# [1349]	validation_0-rmse:256.37375
# [1350]	validation_0-rmse:256.37352
# [1351]	validation_0-rmse:256.36945
# [1352]	validation_0-rmse:256.37472
# [1353]	validation_0-rmse:256.38753
# [1354]	validation_0-rmse:256.38824
# [1355]	validation_0-rmse:256.41432
# [1356]	validation_0-rmse:256.40058
# [1357]	validation_0-rmse:256.39560
# [1358]	validation_0-rmse:256.41341
# [1359]	validation_0-rmse:256.40283
# [1360]	validation_0-rmse:256.40911
# [1361]	validation_0-rmse:256.41767
# [1362]	validation_0-rmse:256.42793
# [1363]	validation_0-rmse:256.42232
# [1364]	validation_0-rmse:256.42147
# [1365]	validation_0-rmse:256.38252
# [1366]	validation_0-rmse:256.41787
# [1367]	validation_0-rmse:256.42012
# [1368]	validation_0-rmse:256.41620
# [1369]	validation_0-rmse:256.42040
# [1370]	validation_0-rmse:256.40715
# [1371]	validation_0-rmse:256.41288
# [1372]	validation_0-rmse:256.41106
# [1373]	validation_0-rmse:256.41233
# [1374]	validation_0-rmse:256.40866
# [1375]	validation_0-rmse:256.41483
# [1376]	validation_0-rmse:256.44548
# [1377]	validation_0-rmse:256.45859
# [1378]	validation_0-rmse:256.45344
# [1379]	validation_0-rmse:256.44455
# [1380]	validation_0-rmse:256.44372
# [1381]	validation_0-rmse:256.44279
# [1382]	validation_0-rmse:256.44823
# [1383]	validation_0-rmse:256.45511
# [1384]	validation_0-rmse:256.43962
# [1385]	validation_0-rmse:256.43929
# [1386]	validation_0-rmse:256.45568
# [1387]	validation_0-rmse:256.45821
# [1388]	validation_0-rmse:256.46201
# [1389]	validation_0-rmse:256.46823
# [1390]	validation_0-rmse:256.47098
# [1391]	validation_0-rmse:256.50476
# [1392]	validation_0-rmse:256.50717
# [1393]	validation_0-rmse:256.48588
# [1394]	validation_0-rmse:256.46244
# [1395]	validation_0-rmse:256.46492
# [1396]	validation_0-rmse:256.46691
# [1397]	validation_0-rmse:256.46555
# [1398]	validation_0-rmse:256.46707
# [1399]	validation_0-rmse:256.47908
# [1400]	validation_0-rmse:256.47839
# ...
# [1547]	validation_0-rmse:113.36265
# [1548]	validation_0-rmse:113.34868
# [1549]	validation_0-rmse:113.32774
# [1550]	validation_0-rmse:113.29853
# [1551]	validation_0-rmse:113.27895
# [1552]	validation_0-rmse:113.26886
# [1553]	validation_0-rmse:113.24464
# [1554]	validation_0-rmse:113.21250
# [1555]	validation_0-rmse:113.19735
# [1556]	validation_0-rmse:113.16147
# [1557]	validation_0-rmse:113.14384
# [1558]	validation_0-rmse:113.12028
# [1559]	validation_0-rmse:113.09463
# [1560]	validation_0-rmse:113.07217
# [1561]	validation_0-rmse:113.05219
# [1562]	validation_0-rmse:113.02847
# [1563]	validation_0-rmse:113.01096
# [1564]	validation_0-rmse:112.99830
# [1565]	validation_0-rmse:112.97853
# [1566]	validation_0-rmse:112.96134
# [1567]	validation_0-rmse:112.94307
# [1568]	validation_0-rmse:112.92296
# [1569]	validation_0-rmse:112.90540
# [1570]	validation_0-rmse:112.89481
# [1571]	validation_0-rmse:112.87171
# [1572]	validation_0-rmse:112.83974
# [1573]	validation_0-rmse:112.82312
# [1574]	validation_0-rmse:112.75825
# [1575]	validation_0-rmse:112.74274
# [1576]	validation_0-rmse:112.71813
# [1577]	validation_0-rmse:112.70610
# [1578]	validation_0-rmse:112.66152
# [1579]	validation_0-rmse:112.64000
# [1580]	validation_0-rmse:112.62694
# [1581]	validation_0-rmse:112.61506
# [1582]	validation_0-rmse:112.56595
# [1583]	validation_0-rmse:112.54397
# [1584]	validation_0-rmse:112.51385
# [1585]	validation_0-rmse:112.49502
# [1586]	validation_0-rmse:112.43080
# [1587]	validation_0-rmse:112.40671
# [1588]	validation_0-rmse:112.38585
# [1589]	validation_0-rmse:112.37580
# [1590]	validation_0-rmse:112.35754
# [1591]	validation_0-rmse:112.34076
# [1592]	validation_0-rmse:112.31678
# [1593]	validation_0-rmse:112.26973
# [1594]	validation_0-rmse:112.24312
# [1595]	validation_0-rmse:112.21498
# [1596]	validation_0-rmse:112.19207
# [1597]	validation_0-rmse:112.16550
# [1598]	validation_0-rmse:112.14263
# [1599]	validation_0-rmse:112.12678
# [1600]	validation_0-rmse:112.07955
# [1601]	validation_0-rmse:112.05808
# [1602]	validation_0-rmse:112.04883
# [1603]	validation_0-rmse:112.02224
# [1604]	validation_0-rmse:111.99475
# [1605]	validation_0-rmse:111.95184
# [1606]	validation_0-rmse:111.94170
# [1607]	validation_0-rmse:111.92894
# [1608]	validation_0-rmse:111.90195
# [1609]	validation_0-rmse:111.88417
# [1610]	validation_0-rmse:111.81318
# [1611]	validation_0-rmse:111.78959
# [1612]	validation_0-rmse:111.75886
# [1613]	validation_0-rmse:111.74216
# [1614]	validation_0-rmse:111.73126
# [1615]	validation_0-rmse:111.70479
# [1616]	validation_0-rmse:111.68831
# [1617]	validation_0-rmse:111.66253
# [1618]	validation_0-rmse:111.64803
# [1619]	validation_0-rmse:111.61445
# [1620]	validation_0-rmse:111.60394
# [1621]	validation_0-rmse:111.58010
# [1622]	validation_0-rmse:111.55097
# [1623]	validation_0-rmse:111.51821
# [1624]	validation_0-rmse:111.50297
# [1625]	validation_0-rmse:111.48974
# [1626]	validation_0-rmse:111.47166
# [1627]	validation_0-rmse:111.44572
# [1628]	validation_0-rmse:111.42163
# [1629]	validation_0-rmse:111.38668
# [1630]	validation_0-rmse:111.35800
# [1631]	validation_0-rmse:111.33520
# [1632]	validation_0-rmse:111.27451
# [1633]	validation_0-rmse:111.20839
# [1634]	validation_0-rmse:111.16397
# [1635]	validation_0-rmse:111.15301
# [1636]	validation_0-rmse:111.11873
# [1637]	validation_0-rmse:111.09099
# [1638]	validation_0-rmse:111.06455
# [1639]	validation_0-rmse:111.05410
# [1640]	validation_0-rmse:111.02416
# [1641]	validation_0-rmse:111.00301
# [1642]	validation_0-rmse:110.99146
# [1643]	validation_0-rmse:110.97688
# [1644]	validation_0-rmse:110.94473
# [1645]	validation_0-rmse:110.91389
# [1646]	validation_0-rmse:110.88181
# [1647]	validation_0-rmse:110.85265
# [1648]	validation_0-rmse:110.83357
# [1649]	validation_0-rmse:110.81060
# [1650]	validation_0-rmse:110.78957
# [1651]	validation_0-rmse:110.77426
# [1652]	validation_0-rmse:110.72366
# [1653]	validation_0-rmse:110.69196
# [1654]	validation_0-rmse:110.68194
# [1655]	validation_0-rmse:110.65633
# [1656]	validation_0-rmse:110.62003
# [1657]	validation_0-rmse:110.59519
# [1658]	validation_0-rmse:110.55679
# [1659]	validation_0-rmse:110.53202
# [1660]	validation_0-rmse:110.49622
# [1661]	validation_0-rmse:110.47974
# [1662]	validation_0-rmse:110.45200
# [1663]	validation_0-rmse:110.43202
# [1664]	validation_0-rmse:110.40841
# [1665]	validation_0-rmse:110.37131
# [1666]	validation_0-rmse:110.34619
# [1667]	validation_0-rmse:110.29845
# [1668]	validation_0-rmse:110.27644
# [1669]	validation_0-rmse:110.25173
# [1670]	validation_0-rmse:110.23324
# [1671]	validation_0-rmse:110.20335
# [1672]	validation_0-rmse:110.17591
# [1673]	validation_0-rmse:110.16303
# [1674]	validation_0-rmse:110.14065
# [1675]	validation_0-rmse:110.12530
# [1676]	validation_0-rmse:110.09067
# [1677]	validation_0-rmse:110.07425
# [1678]	validation_0-rmse:110.04935
# [1679]	validation_0-rmse:110.01608
# [1680]	validation_0-rmse:109.97737
# [1681]	validation_0-rmse:109.95452
# [1682]	validation_0-rmse:109.91311
# [1683]	validation_0-rmse:109.88226
# [1684]	validation_0-rmse:109.86037
# [1685]	validation_0-rmse:109.85094
# [1686]	validation_0-rmse:109.83558
# [1687]	validation_0-rmse:109.81270
# [1688]	validation_0-rmse:109.78376
# [1689]	validation_0-rmse:109.75110
# [1690]	validation_0-rmse:109.73789
# [1691]	validation_0-rmse:109.72584
# [1692]	validation_0-rmse:109.69902
# [1693]	validation_0-rmse:109.68455
# [1694]	validation_0-rmse:109.65861
# [1695]	validation_0-rmse:109.64530
# [1696]	validation_0-rmse:109.63349
# [1697]	validation_0-rmse:109.62074
# [1698]	validation_0-rmse:109.60307
# [1699]	validation_0-rmse:109.58556
# [1700]	validation_0-rmse:109.57913
# [1701]	validation_0-rmse:109.55778
# [1702]	validation_0-rmse:109.51825
# [1703]	validation_0-rmse:109.50777
# [1704]	validation_0-rmse:109.49735
# [1705]	validation_0-rmse:109.47436
# [1706]	validation_0-rmse:109.43836
# [1707]	validation_0-rmse:109.38871
# [1708]	validation_0-rmse:109.35455
# [1709]	validation_0-rmse:109.33784
# [1710]	validation_0-rmse:109.31515
# [1711]	validation_0-rmse:109.30250
# [1712]	validation_0-rmse:109.25937
# [1713]	validation_0-rmse:109.24952
# [1714]	validation_0-rmse:109.24020
# [1715]	validation_0-rmse:109.22025
# [1716]	validation_0-rmse:109.21819
# [1717]	validation_0-rmse:109.20489
# [1718]	validation_0-rmse:109.17759
# [1719]	validation_0-rmse:109.16847
# [1720]	validation_0-rmse:109.14955
# [1721]	validation_0-rmse:109.13138
# [1722]	validation_0-rmse:109.11090
# [1723]	validation_0-rmse:109.08847
# [1724]	validation_0-rmse:109.06919
# [1725]	validation_0-rmse:109.04616
# [1726]	validation_0-rmse:109.04057
# [1727]	validation_0-rmse:109.02019
# [1728]	validation_0-rmse:109.00419
# [1729]	validation_0-rmse:108.97700
# [1730]	validation_0-rmse:108.97194
# [1731]	validation_0-rmse:108.93911
# [1732]	validation_0-rmse:108.92165
# [1733]	validation_0-rmse:108.90360
# [1734]	validation_0-rmse:108.89015
# [1735]	validation_0-rmse:108.87005
# [1736]	validation_0-rmse:108.84316
# [1737]	validation_0-rmse:108.83221
# [1738]	validation_0-rmse:108.81957
# [1739]	validation_0-rmse:108.80691
# [1740]	validation_0-rmse:108.78531
# [1741]	validation_0-rmse:108.73159
# [1742]	validation_0-rmse:108.70710
# [1743]	validation_0-rmse:108.67753
# [1744]	validation_0-rmse:108.66072
# [1745]	validation_0-rmse:108.64377
# [1746]	validation_0-rmse:108.63192
# [1747]	validation_0-rmse:108.60367
# [1748]	validation_0-rmse:108.57887
# [1749]	validation_0-rmse:108.56013
# [1750]	validation_0-rmse:108.53172
# [1751]	validation_0-rmse:108.51458
# [1752]	validation_0-rmse:108.49438
# [1753]	validation_0-rmse:108.47849
# [1754]	validation_0-rmse:108.45758
# [1755]	validation_0-rmse:108.45151
# [1756]	validation_0-rmse:108.44081
# [1757]	validation_0-rmse:108.41301
# [1758]	validation_0-rmse:108.40046
# [1759]	validation_0-rmse:108.37661
# [1760]	validation_0-rmse:108.33252
# [1761]	validation_0-rmse:108.30223
# [1762]	validation_0-rmse:108.26292
# [1763]	validation_0-rmse:108.24541
# [1764]	validation_0-rmse:108.22874
# [1765]	validation_0-rmse:108.20370
# [1766]	validation_0-rmse:108.18272
# [1767]	validation_0-rmse:108.15788
# [1768]	validation_0-rmse:108.11948
# [1769]	validation_0-rmse:108.10191
# [1770]	validation_0-rmse:108.08087
# [1771]	validation_0-rmse:108.06279
# [1772]	validation_0-rmse:108.03108
# [1773]	validation_0-rmse:108.00969
# [1774]	validation_0-rmse:107.99529
# [1775]	validation_0-rmse:107.91592
# [1776]	validation_0-rmse:107.90275
# [1777]	validation_0-rmse:107.88443
# [1778]	validation_0-rmse:107.85748
# [1779]	validation_0-rmse:107.84056
# [1780]	validation_0-rmse:107.81657
# [1781]	validation_0-rmse:107.80164
# [1782]	validation_0-rmse:107.77277
# [1783]	validation_0-rmse:107.74763
# [1784]	validation_0-rmse:107.73146
# [1785]	validation_0-rmse:107.71597
# [1786]	validation_0-rmse:107.69933
# [1787]	validation_0-rmse:107.67847
# [1788]	validation_0-rmse:107.65191
# [1789]	validation_0-rmse:107.63150
# [1790]	validation_0-rmse:107.61237
# [1791]	validation_0-rmse:107.59703
# [1792]	validation_0-rmse:107.57185
# [1793]	validation_0-rmse:107.55792
# [1794]	validation_0-rmse:107.55632
# [1795]	validation_0-rmse:107.54159
# [1796]	validation_0-rmse:107.50871
# [1797]	validation_0-rmse:107.46238
# [1798]	validation_0-rmse:107.44050
# [1799]	validation_0-rmse:107.42070
# [1800]	validation_0-rmse:107.37181
# [1801]	validation_0-rmse:107.33397
# [1802]	validation_0-rmse:107.30450
# [1803]	validation_0-rmse:107.29442
# [1804]	validation_0-rmse:107.26474
# [1805]	validation_0-rmse:107.23838
# [1806]	validation_0-rmse:107.22224
# [1807]	validation_0-rmse:107.21583
# [1808]	validation_0-rmse:107.15860
# [1809]	validation_0-rmse:107.14014
# [1810]	validation_0-rmse:107.10887
# [1811]	validation_0-rmse:107.09223
# [1812]	validation_0-rmse:107.06725
# [1813]	validation_0-rmse:107.04183
# [1814]	validation_0-rmse:107.00614
# [1815]	validation_0-rmse:106.99020
# [1816]	validation_0-rmse:106.96306
# [1817]	validation_0-rmse:106.94448
# [1818]	validation_0-rmse:106.93058
# [1819]	validation_0-rmse:106.91251
# [1820]	validation_0-rmse:106.90555
# [1821]	validation_0-rmse:106.88727
# [1822]	validation_0-rmse:106.84979
# [1823]	validation_0-rmse:106.84105
# [1824]	validation_0-rmse:106.81807
# [1825]	validation_0-rmse:106.80860
# [1826]	validation_0-rmse:106.78869
# [1827]	validation_0-rmse:106.76546
# [1828]	validation_0-rmse:106.75390
# [1829]	validation_0-rmse:106.73773
# [1830]	validation_0-rmse:106.72052
# [1831]	validation_0-rmse:106.70606
# [1832]	validation_0-rmse:106.68017
# [1833]	validation_0-rmse:106.65432
# [1834]	validation_0-rmse:106.62737
# [1835]	validation_0-rmse:106.59531
# [1836]	validation_0-rmse:106.58605
# [1837]	validation_0-rmse:106.56356
# [1838]	validation_0-rmse:106.54757
# [1839]	validation_0-rmse:106.50202
# [1840]	validation_0-rmse:106.48214
# [1841]	validation_0-rmse:106.47072
# [1842]	validation_0-rmse:106.45922
# [1843]	validation_0-rmse:106.42528
# [1844]	validation_0-rmse:106.40181
# [1845]	validation_0-rmse:106.38762
# [1846]	validation_0-rmse:106.36533
# [1847]	validation_0-rmse:106.32620
# [1848]	validation_0-rmse:106.31498
# [1849]	validation_0-rmse:106.27477
# [1850]	validation_0-rmse:106.25498
# [1851]	validation_0-rmse:106.23949
# [1852]	validation_0-rmse:106.19686
# [1853]	validation_0-rmse:106.18408
# [1854]	validation_0-rmse:106.17017
# [1855]	validation_0-rmse:106.15047
# [1856]	validation_0-rmse:106.10026
# [1857]	validation_0-rmse:106.07081
# [1858]	validation_0-rmse:106.01083
# [1859]	validation_0-rmse:105.98909
# [1860]	validation_0-rmse:105.96527
# [1861]	validation_0-rmse:105.90518
# [1862]	validation_0-rmse:105.88287
# [1863]	validation_0-rmse:105.82593
# [1864]	validation_0-rmse:105.80711
# [1865]	validation_0-rmse:105.77982
# [1866]	validation_0-rmse:105.76050
# [1867]	validation_0-rmse:105.74688
# [1868]	validation_0-rmse:105.69098
# [1869]	validation_0-rmse:105.67323
# [1870]	validation_0-rmse:105.65754
# [1871]	validation_0-rmse:105.64017
# [1872]	validation_0-rmse:105.60000
# [1873]	validation_0-rmse:105.59112
# [1874]	validation_0-rmse:105.57246
# [1875]	validation_0-rmse:105.54106
# [1876]	validation_0-rmse:105.52393
# [1877]	validation_0-rmse:105.51168
# [1878]	validation_0-rmse:105.49459
# [1879]	validation_0-rmse:105.48065
# [1880]	validation_0-rmse:105.46874
# [1881]	validation_0-rmse:105.45925
# [1882]	validation_0-rmse:105.44892
# [1883]	validation_0-rmse:105.43540
# [1884]	validation_0-rmse:105.42629
# [1885]	validation_0-rmse:105.40903
# [1886]	validation_0-rmse:105.38783
# [1887]	validation_0-rmse:105.36140
# [1888]	validation_0-rmse:105.34146
# [1889]	validation_0-rmse:105.30898
# [1890]	validation_0-rmse:105.29579
# [1891]	validation_0-rmse:105.28104
# [1892]	validation_0-rmse:105.26387
# [1893]	validation_0-rmse:105.23855
# [1894]	validation_0-rmse:105.22801
# [1895]	validation_0-rmse:105.20353
# [1896]	validation_0-rmse:105.17232
# [1897]	validation_0-rmse:105.15806
# [1898]	validation_0-rmse:105.13365
# [1899]	validation_0-rmse:105.10320
# [1900]	validation_0-rmse:105.08747
# [1901]	validation_0-rmse:105.06157
# [1902]	validation_0-rmse:105.04142
# [1903]	validation_0-rmse:105.01528
# [1904]	validation_0-rmse:104.99290
# [1905]	validation_0-rmse:104.94588
# [1906]	validation_0-rmse:104.92755
# [1907]	validation_0-rmse:104.90523
# [1908]	validation_0-rmse:104.88481
# [1909]	validation_0-rmse:104.86174
# [1910]	validation_0-rmse:104.84627
# [1911]	validation_0-rmse:104.82175
# [1912]	validation_0-rmse:104.78435
# [1913]	validation_0-rmse:104.77143
# [1914]	validation_0-rmse:104.75664
# [1915]	validation_0-rmse:104.73570
# [1916]	validation_0-rmse:104.70200
# [1917]	validation_0-rmse:104.68632
# [1918]	validation_0-rmse:104.66043
# [1919]	validation_0-rmse:104.64679
# [1920]	validation_0-rmse:104.63571
# [1921]	validation_0-rmse:104.61867
# [1922]	validation_0-rmse:104.59744
# [1923]	validation_0-rmse:104.57187
# [1924]	validation_0-rmse:104.54673
# [1925]	validation_0-rmse:104.53929
# [1926]	validation_0-rmse:104.53104
# [1927]	validation_0-rmse:104.50797
# [1928]	validation_0-rmse:104.50068
# [1929]	validation_0-rmse:104.47366
# [1930]	validation_0-rmse:104.44523
# [1931]	validation_0-rmse:104.41830
# [1932]	validation_0-rmse:104.40117
# [1933]	validation_0-rmse:104.38449
# [1934]	validation_0-rmse:104.36412
# [1935]	validation_0-rmse:104.33463
# [1936]	validation_0-rmse:104.32558
# [1937]	validation_0-rmse:104.30666
# [1938]	validation_0-rmse:104.29368
# [1939]	validation_0-rmse:104.28416
# [1940]	validation_0-rmse:104.25527
# [1941]	validation_0-rmse:104.24459
# [1942]	validation_0-rmse:104.22836
# [1943]	validation_0-rmse:104.21580
# [1944]	validation_0-rmse:104.20501
# [1945]	validation_0-rmse:104.16464
# [1946]	validation_0-rmse:104.15149
# [1947]	validation_0-rmse:104.13668
# [1948]	validation_0-rmse:104.12160
# [1949]	validation_0-rmse:104.09825
# [1950]	validation_0-rmse:104.08700
# [1951]	validation_0-rmse:104.07183
# [1952]	validation_0-rmse:104.04785
# [1953]	validation_0-rmse:104.03444
# [1954]	validation_0-rmse:103.99000
# [1955]	validation_0-rmse:103.96067
# [1956]	validation_0-rmse:103.94933
# [1957]	validation_0-rmse:103.93260
# [1958]	validation_0-rmse:103.90925
# [1959]	validation_0-rmse:103.90285
# [1960]	validation_0-rmse:103.89033
# [1961]	validation_0-rmse:103.87669
# [1962]	validation_0-rmse:103.85853
# [1963]	validation_0-rmse:103.84093
# [1964]	validation_0-rmse:103.81805
# [1965]	validation_0-rmse:103.79134
# [1966]	validation_0-rmse:103.75141
# [1967]	validation_0-rmse:103.74046
# [1968]	validation_0-rmse:103.72409
# [1969]	validation_0-rmse:103.69556
# [1970]	validation_0-rmse:103.67724
# [1971]	validation_0-rmse:103.65742
# [1972]	validation_0-rmse:103.64572
# [1973]	validation_0-rmse:103.63689
# [1974]	validation_0-rmse:103.61091
# [1975]	validation_0-rmse:103.59387
# [1976]	validation_0-rmse:103.58215
# [1977]	validation_0-rmse:103.56258
# [1978]	validation_0-rmse:103.54361
# [1979]	validation_0-rmse:103.52506
# [1980]	validation_0-rmse:103.51310
# [1981]	validation_0-rmse:103.49885
# [1982]	validation_0-rmse:103.47556
# [1983]	validation_0-rmse:103.46098
# [1984]	validation_0-rmse:103.44591
# [1985]	validation_0-rmse:103.40604
# [1986]	validation_0-rmse:103.39407
# [1987]	validation_0-rmse:103.37892
# [1988]	validation_0-rmse:103.33551
# [1989]	validation_0-rmse:103.32234
# [1990]	validation_0-rmse:103.30180
# [1991]	validation_0-rmse:103.27090
# [1992]	validation_0-rmse:103.23407
# [1993]	validation_0-rmse:103.21729
# [1994]	validation_0-rmse:103.20227
# [1995]	validation_0-rmse:103.19414
# [1996]	validation_0-rmse:103.18710
# [1997]	validation_0-rmse:103.16525
# [1998]	validation_0-rmse:103.15184
# [1999]	validation_0-rmse:103.10194
# Wrote: ./artifacts_20250827-185646\submission_20250827-185646.csv
# submission.csv saved (ready to Submit to Competition)
